# %%
#importing necessary python packages
import pandas as pd
import numpy as np
import os
from keras.callbacks import ModelCheckpoint
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error 
import warnings 
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', category=DeprecationWarning)
# Out:
# Using TensorFlow backend.

# %%
# Importing the dataset
dataset1 = pd.read_excel('LUAD_clinical.xlsx',index_col=0)
dataset2 = pd.read_excel('LUAD_flux.xlsx',index_col=0)
dataset3 = pd.read_excel('LUAD_Genes.xlsx',index_col=0)

# %%
dataset1.head()
# Out:
#                  Diagnosis Age  Birth from Initial Pathologic Diagnosis Date  \
# Sample ID
# TCGA-05-4244-01           70.0                                      -25752.0
# TCGA-05-4249-01           67.0                                      -24532.0
# TCGA-05-4250-01           79.0                                      -29068.0
# TCGA-05-4382-01           68.0                                      -24868.0
# TCGA-05-4384-01           66.0                                      -24411.0
#
#                  Last Alive Less Initial Pathologic Diagnosis Date Calculated Day Value  \
# Sample ID
# TCGA-05-4244-01                                                  0
# TCGA-05-4249-01                                                  0
# TCGA-05-4250-01                                                  0
# TCGA-05-4382-01                                                  0
# TCGA-05-4384-01                                                  0
#
#                  Fraction Genome Altered  Year Cancer Initial Diagnosis  \
# Sample ID
# TCGA-05-4244-01                 0.456523                         2009.0
# TCGA-05-4249-01                 0.222128                         2007.0
# TCGA-05-4250-01                 0.236200                         2007.0
# TCGA-05-4382-01                 0.085449                         2009.0
# TCGA-05-4384-01                 0.066063                         2009.0
#
#                  Longest Dimension  Number of Samples Per Patient  \
# Sample ID
# TCGA-05-4244-01                1.1                              1
# TCGA-05-4249-01                1.4                              1
# TCGA-05-4250-01                1.2                              1
# TCGA-05-4382-01                0.9                              1
# TCGA-05-4384-01                0.8                              1
#
#                  Sample type id  Shortest Dimension  \
# Sample ID
# TCGA-05-4244-01               1                 0.3
# TCGA-05-4249-01               1                 0.4
# TCGA-05-4250-01               1                 0.3
# TCGA-05-4382-01               1                 0.3
# TCGA-05-4384-01               1                 0.4
#
#                  Specimen Second Longest Dimension  ...  \
# Sample ID                                           ...
# TCGA-05-4244-01                                0.9  ...
# TCGA-05-4249-01                                0.8  ...
# TCGA-05-4250-01                                0.7  ...
# TCGA-05-4382-01                                0.8  ...
# TCGA-05-4384-01                                0.8  ...
#
#                  Tissue Source Site_NJ  Tissue Source Site_O1  \
# Sample ID
# TCGA-05-4244-01                      0                      0
# TCGA-05-4249-01                      0                      0
# TCGA-05-4250-01                      0                      0
# TCGA-05-4382-01                      0                      0
# TCGA-05-4384-01                      0                      0
#
#                  Tissue Source Site_S2  Person Neoplasm Status_TUMOR FREE  \
# Sample ID
# TCGA-05-4244-01                      0                                  1
# TCGA-05-4249-01                      0                                  1
# TCGA-05-4250-01                      0                                  1
# TCGA-05-4382-01                      0                                  1
# TCGA-05-4384-01                      0                                  1
#
#                  Person Neoplasm Status_WITH TUMOR  Vial number_A  \
# Sample ID
# TCGA-05-4244-01                                  0              1
# TCGA-05-4249-01                                  0              1
# TCGA-05-4250-01                                  0              1
# TCGA-05-4382-01                                  0              1
# TCGA-05-4384-01                                  0              1
#
#                  Vial number_B  Patient's Vital Status_Alive  \
# Sample ID
# TCGA-05-4244-01              0                             1
# TCGA-05-4249-01              0                             1
# TCGA-05-4250-01              0                             0
# TCGA-05-4382-01              0                             1
# TCGA-05-4384-01              0                             1
#
#                  Patient's Vital Status_Dead  Overall Survival (Months)2
# Sample ID
# TCGA-05-4244-01                            0                        0.00
# TCGA-05-4249-01                            0                       50.03
# TCGA-05-4250-01                            1                        3.98
# TCGA-05-4382-01                            0                       19.94
# TCGA-05-4384-01                            0                       13.99
#
# [5 rows x 347 columns]

# %%
del dataset1['Overall Survival (Months)2']

# %%
del dataset2['Overall Survival (Months)']

# %%
Genes_flux = dataset1.merge(dataset2,left_index=True,right_index=True)

# %%
Genes_Flux_Clinical = Genes_flux.merge(dataset3,left_index=True,right_index=True)

# %%
dt=Genes_Flux_Clinical

# %%
dt.head()
# Out:
#                  Diagnosis Age  Birth from Initial Pathologic Diagnosis Date  \
# Sample ID
# TCGA-05-4244-01           70.0                                      -25752.0
# TCGA-05-4249-01           67.0                                      -24532.0
# TCGA-05-4250-01           79.0                                      -29068.0
# TCGA-05-4382-01           68.0                                      -24868.0
# TCGA-05-4384-01           66.0                                      -24411.0
#
#                  Last Alive Less Initial Pathologic Diagnosis Date Calculated Day Value  \
# Sample ID
# TCGA-05-4244-01                                                  0
# TCGA-05-4249-01                                                  0
# TCGA-05-4250-01                                                  0
# TCGA-05-4382-01                                                  0
# TCGA-05-4384-01                                                  0
#
#                  Fraction Genome Altered  Year Cancer Initial Diagnosis  \
# Sample ID
# TCGA-05-4244-01                 0.456523                         2009.0
# TCGA-05-4249-01                 0.222128                         2007.0
# TCGA-05-4250-01                 0.236200                         2007.0
# TCGA-05-4382-01                 0.085449                         2009.0
# TCGA-05-4384-01                 0.066063                         2009.0
#
#                  Longest Dimension  Number of Samples Per Patient  \
# Sample ID
# TCGA-05-4244-01                1.1                              1
# TCGA-05-4249-01                1.4                              1
# TCGA-05-4250-01                1.2                              1
# TCGA-05-4382-01                0.9                              1
# TCGA-05-4384-01                0.8                              1
#
#                  Sample type id  Shortest Dimension  \
# Sample ID
# TCGA-05-4244-01               1                 0.3
# TCGA-05-4249-01               1                 0.4
# TCGA-05-4250-01               1                 0.3
# TCGA-05-4382-01               1                 0.3
# TCGA-05-4384-01               1                 0.4
#
#                  Specimen Second Longest Dimension  ...    SLTM    SLU7  \
# Sample ID                                           ...
# TCGA-05-4244-01                                0.9  ... -1.1877  3.4584
# TCGA-05-4249-01                                0.8  ... -0.5540  0.7962
# TCGA-05-4250-01                                0.7  ... -1.3805  0.0730
# TCGA-05-4382-01                                0.8  ... -0.3885 -1.5611
# TCGA-05-4384-01                                0.8  ...  0.4227  0.7651
#
#                  SLURP1   SMAD2   SMAD3   SMAD4   SMAD5   SMAD6   SMAD7  \
# Sample ID
# TCGA-05-4244-01 -0.2752 -0.7736 -0.6896 -0.0017  0.1779 -0.6433  0.7445
# TCGA-05-4249-01 -0.2752 -0.6214  0.0881  1.3829  2.3203 -0.4918  0.0368
# TCGA-05-4250-01 -0.2752 -1.3034  1.0473 -0.3628  0.0526 -0.8961 -1.1245
# TCGA-05-4382-01 -0.2752  0.3948 -0.6485  0.5367 -0.9418 -0.1446  2.2863
# TCGA-05-4384-01 -0.2752  0.2285 -0.4482  0.5020  0.5863  0.3185 -0.3951
#
#                  Survival
# Sample ID
# TCGA-05-4244-01       0.00
# TCGA-05-4249-01      50.03
# TCGA-05-4250-01       3.98
# TCGA-05-4382-01      19.94
# TCGA-05-4384-01      13.99
#
# [5 rows x 17114 columns]

# %%
del dt['Patient\'s Vital Status_Dead']
del dt['Patient\'s Vital Status_Alive']

# %%
dt.shape
# Out:
# (517, 17112)

# %%
X = dt.iloc[:,0:17111].values
y = dt.iloc[:, -1].values

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=0)

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)
X_val = sc_X.fit_transform(X_val)

# %%
sc_y = StandardScaler()
y_train = np.squeeze(sc_y.fit_transform(y_train.reshape(-1, 1)))
y_val = np.squeeze(sc_y.transform(y_val.reshape(-1, 1)))
y_test = np.squeeze(sc_y.transform(y_test.reshape(-1, 1)))

# %%
#Create Deep Neural Network Architecuture
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout

NN_model = Sequential()

# The Input Layer :
NN_model.add(Dense(128, kernel_initializer='normal',input_dim = X_train.shape[1], activation='relu'))

# The Hidden Layers :
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))

# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))

# Compile the network :
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
NN_model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_28 (Dense)             (None, 128)               2190336
# _________________________________________________________________
# dense_29 (Dense)             (None, 256)               33024
# _________________________________________________________________
# dense_30 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_31 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_32 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 2,355,201
# Trainable params: 2,355,201
# Non-trainable params: 0
# _________________________________________________________________

# %%
NN_model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split = 0.2)
# Out:
# Train on 264 samples, validate on 66 samples
# Epoch 1/100
# 264/264 [==============================] - 0s 1ms/sample - loss: 0.8199 - mean_absolute_error: 0.8199 - val_loss: 0.5539 - val_mean_absolute_error: 0.5539
# Epoch 2/100
# 264/264 [==============================] - 0s 499us/sample - loss: 0.6483 - mean_absolute_error: 0.6483 - val_loss: 0.5586 - val_mean_absolute_error: 0.5586
# Epoch 3/100
# 264/264 [==============================] - 0s 491us/sample - loss: 0.5190 - mean_absolute_error: 0.5190 - val_loss: 0.7524 - val_mean_absolute_error: 0.7524
# Epoch 4/100
# 264/264 [==============================] - 0s 485us/sample - loss: 0.5098 - mean_absolute_error: 0.5098 - val_loss: 0.5146 - val_mean_absolute_error: 0.5146
# Epoch 5/100
# 264/264 [==============================] - 0s 493us/sample - loss: 0.4471 - mean_absolute_error: 0.4471 - val_loss: 0.5327 - val_mean_absolute_error: 0.5327
# Epoch 6/100
# 264/264 [==============================] - 0s 536us/sample - loss: 0.3879 - mean_absolute_error: 0.3879 - val_loss: 0.5527 - val_mean_absolute_error: 0.5527
# Epoch 7/100
# 264/264 [==============================] - 0s 498us/sample - loss: 0.3758 - mean_absolute_error: 0.3758 - val_loss: 0.4757 - val_mean_absolute_error: 0.4757
# Epoch 8/100
# 264/264 [==============================] - 0s 511us/sample - loss: 0.3366 - mean_absolute_error: 0.3366 - val_loss: 0.5409 - val_mean_absolute_error: 0.5409
# Epoch 9/100
# 264/264 [==============================] - 0s 494us/sample - loss: 0.3346 - mean_absolute_error: 0.3346 - val_loss: 0.5027 - val_mean_absolute_error: 0.5027
# Epoch 10/100
# 264/264 [==============================] - 0s 495us/sample - loss: 0.3177 - mean_absolute_error: 0.3177 - val_loss: 0.5107 - val_mean_absolute_error: 0.5107
# Epoch 11/100
# 264/264 [==============================] - 0s 492us/sample - loss: 0.2671 - mean_absolute_error: 0.2671 - val_loss: 0.5397 - val_mean_absolute_error: 0.5397
# Epoch 12/100
# 264/264 [==============================] - 0s 502us/sample - loss: 0.2824 - mean_absolute_error: 0.2824 - val_loss: 0.4898 - val_mean_absolute_error: 0.4898
# Epoch 13/100
# 264/264 [==============================] - 0s 502us/sample - loss: 0.2366 - mean_absolute_error: 0.2366 - val_loss: 0.5349 - val_mean_absolute_error: 0.5349
# Epoch 14/100
# 264/264 [==============================] - 0s 507us/sample - loss: 0.2143 - mean_absolute_error: 0.2143 - val_loss: 0.5023 - val_mean_absolute_error: 0.5023
# Epoch 15/100
# 264/264 [==============================] - 0s 508us/sample - loss: 0.2265 - mean_absolute_error: 0.2265 - val_loss: 0.5194 - val_mean_absolute_error: 0.5194
# Epoch 16/100
# 264/264 [==============================] - 0s 504us/sample - loss: 0.2192 - mean_absolute_error: 0.2192 - val_loss: 0.5489 - val_mean_absolute_error: 0.5489
# Epoch 17/100
# 264/264 [==============================] - 0s 533us/sample - loss: 0.1879 - mean_absolute_error: 0.1879 - val_loss: 0.5707 - val_mean_absolute_error: 0.5707
# Epoch 18/100
# 264/264 [==============================] - 0s 559us/sample - loss: 0.1858 - mean_absolute_error: 0.1858 - val_loss: 0.5815 - val_mean_absolute_error: 0.5815
# Epoch 19/100
# 264/264 [==============================] - 0s 549us/sample - loss: 0.1945 - mean_absolute_error: 0.1945 - val_loss: 0.5102 - val_mean_absolute_error: 0.5102
# Epoch 20/100
# 264/264 [==============================] - 0s 515us/sample - loss: 0.1971 - mean_absolute_error: 0.1971 - val_loss: 0.5449 - val_mean_absolute_error: 0.5449
# Epoch 21/100
# 264/264 [==============================] - 0s 526us/sample - loss: 0.1818 - mean_absolute_error: 0.1818 - val_loss: 0.5343 - val_mean_absolute_error: 0.5343
# Epoch 22/100
# 264/264 [==============================] - 0s 493us/sample - loss: 0.1722 - mean_absolute_error: 0.1722 - val_loss: 0.5312 - val_mean_absolute_error: 0.5312
# Epoch 23/100
# 264/264 [==============================] - 0s 506us/sample - loss: 0.1717 - mean_absolute_error: 0.1717 - val_loss: 0.5140 - val_mean_absolute_error: 0.5140
# Epoch 24/100
# 264/264 [==============================] - 0s 514us/sample - loss: 0.1900 - mean_absolute_error: 0.1900 - val_loss: 0.5616 - val_mean_absolute_error: 0.5616
# Epoch 25/100
# 264/264 [==============================] - 0s 521us/sample - loss: 0.1845 - mean_absolute_error: 0.1845 - val_loss: 0.4740 - val_mean_absolute_error: 0.4740
# Epoch 26/100
# 264/264 [==============================] - 0s 564us/sample - loss: 0.1863 - mean_absolute_error: 0.1863 - val_loss: 0.5355 - val_mean_absolute_error: 0.5355
# Epoch 27/100
# 264/264 [==============================] - 0s 539us/sample - loss: 0.1695 - mean_absolute_error: 0.1695 - val_loss: 0.5370 - val_mean_absolute_error: 0.5370
# Epoch 28/100
# 264/264 [==============================] - 0s 491us/sample - loss: 0.1657 - mean_absolute_error: 0.1657 - val_loss: 0.5930 - val_mean_absolute_error: 0.5930
# Epoch 29/100
# 264/264 [==============================] - 0s 501us/sample - loss: 0.2061 - mean_absolute_error: 0.2061 - val_loss: 0.4840 - val_mean_absolute_error: 0.4840
# Epoch 30/100
# 264/264 [==============================] - 0s 502us/sample - loss: 0.1753 - mean_absolute_error: 0.1753 - val_loss: 0.5529 - val_mean_absolute_error: 0.5529
# Epoch 31/100
# 264/264 [==============================] - 0s 504us/sample - loss: 0.1793 - mean_absolute_error: 0.1793 - val_loss: 0.5096 - val_mean_absolute_error: 0.5096
# Epoch 32/100
# 264/264 [==============================] - 0s 530us/sample - loss: 0.1492 - mean_absolute_error: 0.1492 - val_loss: 0.5656 - val_mean_absolute_error: 0.5656
# Epoch 33/100
# 264/264 [==============================] - 0s 516us/sample - loss: 0.1877 - mean_absolute_error: 0.1877 - val_loss: 0.5074 - val_mean_absolute_error: 0.5074
# Epoch 34/100
# 264/264 [==============================] - 0s 496us/sample - loss: 0.1694 - mean_absolute_error: 0.1694 - val_loss: 0.5618 - val_mean_absolute_error: 0.5618
# Epoch 35/100
# 264/264 [==============================] - 0s 589us/sample - loss: 0.1406 - mean_absolute_error: 0.1406 - val_loss: 0.5126 - val_mean_absolute_error: 0.5126
# Epoch 36/100
# 264/264 [==============================] - 0s 553us/sample - loss: 0.1336 - mean_absolute_error: 0.1336 - val_loss: 0.5311 - val_mean_absolute_error: 0.5311
# Epoch 37/100
# 264/264 [==============================] - 0s 540us/sample - loss: 0.1180 - mean_absolute_error: 0.1180 - val_loss: 0.5652 - val_mean_absolute_error: 0.5652
# Epoch 38/100
# 264/264 [==============================] - 0s 535us/sample - loss: 0.1485 - mean_absolute_error: 0.1485 - val_loss: 0.4870 - val_mean_absolute_error: 0.4870
# Epoch 39/100
# 264/264 [==============================] - 0s 521us/sample - loss: 0.1591 - mean_absolute_error: 0.1591 - val_loss: 0.4813 - val_mean_absolute_error: 0.4813
# Epoch 40/100
# 264/264 [==============================] - 0s 523us/sample - loss: 0.1271 - mean_absolute_error: 0.1271 - val_loss: 0.5025 - val_mean_absolute_error: 0.5025
# Epoch 41/100
# 264/264 [==============================] - 0s 514us/sample - loss: 0.1329 - mean_absolute_error: 0.1329 - val_loss: 0.4860 - val_mean_absolute_error: 0.4860
# Epoch 42/100
# 264/264 [==============================] - 0s 534us/sample - loss: 0.1240 - mean_absolute_error: 0.1240 - val_loss: 0.5518 - val_mean_absolute_error: 0.5518
# Epoch 43/100
# 264/264 [==============================] - 0s 535us/sample - loss: 0.1161 - mean_absolute_error: 0.1161 - val_loss: 0.4981 - val_mean_absolute_error: 0.4981
# Epoch 44/100
# 264/264 [==============================] - 0s 530us/sample - loss: 0.1264 - mean_absolute_error: 0.1264 - val_loss: 0.5687 - val_mean_absolute_error: 0.5687
# Epoch 45/100
# 264/264 [==============================] - 0s 528us/sample - loss: 0.1027 - mean_absolute_error: 0.1027 - val_loss: 0.5335 - val_mean_absolute_error: 0.5335
# Epoch 46/100
# 264/264 [==============================] - 0s 542us/sample - loss: 0.1054 - mean_absolute_error: 0.1054 - val_loss: 0.5661 - val_mean_absolute_error: 0.5661
# Epoch 47/100
# 264/264 [==============================] - 0s 515us/sample - loss: 0.1028 - mean_absolute_error: 0.1028 - val_loss: 0.5382 - val_mean_absolute_error: 0.5382
# Epoch 48/100
# 264/264 [==============================] - 0s 533us/sample - loss: 0.1006 - mean_absolute_error: 0.1006 - val_loss: 0.5500 - val_mean_absolute_error: 0.5500
# Epoch 49/100
# 264/264 [==============================] - 0s 559us/sample - loss: 0.0968 - mean_absolute_error: 0.0968 - val_loss: 0.5084 - val_mean_absolute_error: 0.5084
# Epoch 50/100
# 264/264 [==============================] - 0s 562us/sample - loss: 0.0883 - mean_absolute_error: 0.0883 - val_loss: 0.5309 - val_mean_absolute_error: 0.5309
# Epoch 51/100
# 264/264 [==============================] - 0s 553us/sample - loss: 0.0900 - mean_absolute_error: 0.0900 - val_loss: 0.4937 - val_mean_absolute_error: 0.4937
# Epoch 52/100
# 264/264 [==============================] - 0s 496us/sample - loss: 0.0961 - mean_absolute_error: 0.0961 - val_loss: 0.5428 - val_mean_absolute_error: 0.5428
# Epoch 53/100
# 264/264 [==============================] - 0s 475us/sample - loss: 0.0855 - mean_absolute_error: 0.0855 - val_loss: 0.4975 - val_mean_absolute_error: 0.4975
# Epoch 54/100
# 264/264 [==============================] - 0s 545us/sample - loss: 0.1132 - mean_absolute_error: 0.1132 - val_loss: 0.5487 - val_mean_absolute_error: 0.5487
# Epoch 55/100
# 264/264 [==============================] - 0s 557us/sample - loss: 0.1023 - mean_absolute_error: 0.1023 - val_loss: 0.5402 - val_mean_absolute_error: 0.5402
# Epoch 56/100
# 264/264 [==============================] - 0s 486us/sample - loss: 0.1190 - mean_absolute_error: 0.1190 - val_loss: 0.5485 - val_mean_absolute_error: 0.5485
# Epoch 57/100
# 264/264 [==============================] - 0s 483us/sample - loss: 0.1147 - mean_absolute_error: 0.1147 - val_loss: 0.5261 - val_mean_absolute_error: 0.5261
# Epoch 58/100
# 264/264 [==============================] - 0s 492us/sample - loss: 0.1072 - mean_absolute_error: 0.1072 - val_loss: 0.5406 - val_mean_absolute_error: 0.5406
# Epoch 59/100
# 264/264 [==============================] - 0s 532us/sample - loss: 0.1078 - mean_absolute_error: 0.1078 - val_loss: 0.5258 - val_mean_absolute_error: 0.5258
# Epoch 60/100
# 264/264 [==============================] - 0s 562us/sample - loss: 0.0899 - mean_absolute_error: 0.0899 - val_loss: 0.5344 - val_mean_absolute_error: 0.5344
# Epoch 61/100
# 264/264 [==============================] - 0s 514us/sample - loss: 0.1092 - mean_absolute_error: 0.1092 - val_loss: 0.5669 - val_mean_absolute_error: 0.5669
# Epoch 62/100
# 264/264 [==============================] - 0s 479us/sample - loss: 0.1148 - mean_absolute_error: 0.1148 - val_loss: 0.5227 - val_mean_absolute_error: 0.5227
# Epoch 63/100
# 264/264 [==============================] - 0s 495us/sample - loss: 0.1290 - mean_absolute_error: 0.1290 - val_loss: 0.5621 - val_mean_absolute_error: 0.5621
# Epoch 64/100
# 264/264 [==============================] - 0s 489us/sample - loss: 0.1358 - mean_absolute_error: 0.1358 - val_loss: 0.5220 - val_mean_absolute_error: 0.5220
# Epoch 65/100
# 264/264 [==============================] - 0s 474us/sample - loss: 0.1046 - mean_absolute_error: 0.1046 - val_loss: 0.5516 - val_mean_absolute_error: 0.5516
# Epoch 66/100
# 264/264 [==============================] - 0s 473us/sample - loss: 0.1198 - mean_absolute_error: 0.1198 - val_loss: 0.5575 - val_mean_absolute_error: 0.5575
# Epoch 67/100
# 264/264 [==============================] - 0s 486us/sample - loss: 0.0943 - mean_absolute_error: 0.0943 - val_loss: 0.5584 - val_mean_absolute_error: 0.5584
# Epoch 68/100
# 264/264 [==============================] - 0s 479us/sample - loss: 0.1075 - mean_absolute_error: 0.1075 - val_loss: 0.5517 - val_mean_absolute_error: 0.5517
# Epoch 69/100
# 264/264 [==============================] - 0s 476us/sample - loss: 0.0989 - mean_absolute_error: 0.0989 - val_loss: 0.5217 - val_mean_absolute_error: 0.5217
# Epoch 70/100
# 264/264 [==============================] - 0s 485us/sample - loss: 0.1161 - mean_absolute_error: 0.1161 - val_loss: 0.5752 - val_mean_absolute_error: 0.5752
# Epoch 71/100
# 264/264 [==============================] - 0s 481us/sample - loss: 0.0982 - mean_absolute_error: 0.0982 - val_loss: 0.5151 - val_mean_absolute_error: 0.5151
# Epoch 72/100
# 264/264 [==============================] - 0s 479us/sample - loss: 0.0933 - mean_absolute_error: 0.0933 - val_loss: 0.5716 - val_mean_absolute_error: 0.5716
# Epoch 73/100
# 264/264 [==============================] - 0s 486us/sample - loss: 0.1026 - mean_absolute_error: 0.1026 - val_loss: 0.5122 - val_mean_absolute_error: 0.5122
# Epoch 74/100
# 264/264 [==============================] - 0s 486us/sample - loss: 0.1127 - mean_absolute_error: 0.1127 - val_loss: 0.5959 - val_mean_absolute_error: 0.5959
# Epoch 75/100
# 264/264 [==============================] - 0s 485us/sample - loss: 0.1016 - mean_absolute_error: 0.1016 - val_loss: 0.5185 - val_mean_absolute_error: 0.5185
# Epoch 76/100
# 264/264 [==============================] - 0s 481us/sample - loss: 0.1014 - mean_absolute_error: 0.1014 - val_loss: 0.6027 - val_mean_absolute_error: 0.6027
# Epoch 77/100
# 264/264 [==============================] - 0s 484us/sample - loss: 0.0988 - mean_absolute_error: 0.0988 - val_loss: 0.5089 - val_mean_absolute_error: 0.5089
# Epoch 78/100
# 264/264 [==============================] - 0s 483us/sample - loss: 0.1355 - mean_absolute_error: 0.1355 - val_loss: 0.5235 - val_mean_absolute_error: 0.5235
# Epoch 79/100
# 264/264 [==============================] - 0s 477us/sample - loss: 0.1123 - mean_absolute_error: 0.1123 - val_loss: 0.5138 - val_mean_absolute_error: 0.5138
# Epoch 80/100
# 264/264 [==============================] - 0s 493us/sample - loss: 0.0984 - mean_absolute_error: 0.0984 - val_loss: 0.5530 - val_mean_absolute_error: 0.5530
# Epoch 81/100
# 264/264 [==============================] - 0s 495us/sample - loss: 0.0897 - mean_absolute_error: 0.0897 - val_loss: 0.5091 - val_mean_absolute_error: 0.5091
# Epoch 82/100
# 264/264 [==============================] - 0s 493us/sample - loss: 0.1157 - mean_absolute_error: 0.1157 - val_loss: 0.5523 - val_mean_absolute_error: 0.5523
# Epoch 83/100
# 264/264 [==============================] - 0s 485us/sample - loss: 0.0940 - mean_absolute_error: 0.0940 - val_loss: 0.5496 - val_mean_absolute_error: 0.5496
# Epoch 84/100
# 264/264 [==============================] - 0s 493us/sample - loss: 0.1089 - mean_absolute_error: 0.1089 - val_loss: 0.5666 - val_mean_absolute_error: 0.5666
# Epoch 85/100
# 264/264 [==============================] - 0s 491us/sample - loss: 0.0877 - mean_absolute_error: 0.0877 - val_loss: 0.5486 - val_mean_absolute_error: 0.5486
# Epoch 86/100
# 264/264 [==============================] - 0s 486us/sample - loss: 0.0825 - mean_absolute_error: 0.0825 - val_loss: 0.5773 - val_mean_absolute_error: 0.5773
# Epoch 87/100
# 264/264 [==============================] - 0s 490us/sample - loss: 0.0929 - mean_absolute_error: 0.0929 - val_loss: 0.5720 - val_mean_absolute_error: 0.5720
# Epoch 88/100
# 264/264 [==============================] - 0s 490us/sample - loss: 0.0810 - mean_absolute_error: 0.0810 - val_loss: 0.5867 - val_mean_absolute_error: 0.5867
# Epoch 89/100
# 264/264 [==============================] - 0s 524us/sample - loss: 0.0934 - mean_absolute_error: 0.0934 - val_loss: 0.5473 - val_mean_absolute_error: 0.5473
# Epoch 90/100
# 264/264 [==============================] - 0s 488us/sample - loss: 0.0978 - mean_absolute_error: 0.0978 - val_loss: 0.5634 - val_mean_absolute_error: 0.5634
# Epoch 91/100
# 264/264 [==============================] - 0s 487us/sample - loss: 0.0872 - mean_absolute_error: 0.0872 - val_loss: 0.5763 - val_mean_absolute_error: 0.5763
# Epoch 92/100
# 264/264 [==============================] - 0s 485us/sample - loss: 0.0895 - mean_absolute_error: 0.0895 - val_loss: 0.5637 - val_mean_absolute_error: 0.5637
# Epoch 93/100
# 264/264 [==============================] - 0s 498us/sample - loss: 0.0821 - mean_absolute_error: 0.0821 - val_loss: 0.5280 - val_mean_absolute_error: 0.5280
# Epoch 94/100
# 264/264 [==============================] - 0s 485us/sample - loss: 0.0829 - mean_absolute_error: 0.0829 - val_loss: 0.5484 - val_mean_absolute_error: 0.5484
# Epoch 95/100
# 264/264 [==============================] - 0s 484us/sample - loss: 0.0967 - mean_absolute_error: 0.0967 - val_loss: 0.5295 - val_mean_absolute_error: 0.5295
# Epoch 96/100
# 264/264 [==============================] - 0s 480us/sample - loss: 0.0857 - mean_absolute_error: 0.0857 - val_loss: 0.5548 - val_mean_absolute_error: 0.5548
# Epoch 97/100
# 264/264 [==============================] - 0s 503us/sample - loss: 0.0802 - mean_absolute_error: 0.0802 - val_loss: 0.5590 - val_mean_absolute_error: 0.5590
# Epoch 98/100
# 264/264 [==============================] - 0s 473us/sample - loss: 0.0836 - mean_absolute_error: 0.0836 - val_loss: 0.5215 - val_mean_absolute_error: 0.5215
# Epoch 99/100
# 264/264 [==============================] - 0s 489us/sample - loss: 0.0954 - mean_absolute_error: 0.0954 - val_loss: 0.6009 - val_mean_absolute_error: 0.6009
# Epoch 100/100
# 264/264 [==============================] - 0s 483us/sample - loss: 0.0993 - mean_absolute_error: 0.0993 - val_loss: 0.5635 - val_mean_absolute_error: 0.5635

# %%
#Predicting the Validation set results
y_predval = NN_model.predict(X_val)

# %%
# Print result of MAE
from sklearn import metrics
print(metrics.mean_absolute_error(y_val, y_predval))

# Print result of MSE
print(metrics.mean_squared_error(y_val, y_predval))

# Print result of RMSE
print(np.sqrt(metrics.mean_squared_error(y_val, y_predval)))

from sklearn.metrics import r2_score
accuracy=r2_score(y_val,y_predval)

print('R2 Score')
print(accuracy)
# Out:
# 0.6663438484411868
# 0.8394421616378663
# 0.9162107626730142
# R2 Score
# -0.20494477985211534

# %%
from keras import metrics
NN_model.compile(loss='mse', optimizer='adam', metrics=[metrics.mean_squared_error, metrics.mean_absolute_error, metrics.mean_absolute_percentage_error, metrics.cosine_proximity])

# %%
# Visualising the Random Forest Regression Results
# Loading Packages
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import r2_score
#from sklearn import linear_model
from sklearn import datasets
from scipy.integrate import simps

# Function for Regression Error Characteritic Curve

def REC(y_val , y_predval):
    
    # initilizing the lists
    Accuracy = []
    
    # initializing the values for Epsilon
    Begin_Range = 0
    End_Range = 1.5
    Interval_Size = 0.01
    
    # List of epsilons
    Epsilon = np.arange(Begin_Range , End_Range , Interval_Size)
    
    # Main Loops
    for i in range(len(Epsilon)):
        count = 0.0
        for j in range(len(y_val)):
            if np.linalg.norm(y_val[j] - y_predval[j]) / np.sqrt( np.linalg.norm(y_val[j]) **2 + np.linalg.norm(y_predval[j])**2 ) < Epsilon[i]:
                count = count + 1
        
        Accuracy.append(count/len(y_val))
    
    # Calculating Area Under Curve using Simpson's rule
    AUC = simps(Accuracy , Epsilon ) / End_Range
        
    # returning epsilon , accuracy , area under curve    
    return Epsilon , Accuracy , AUC

# finding the deviation and accuracy, and area under curve for plotting
Deviation, Accuracy, AUC = REC(y_val, y_predval)

# Calculating R^2 of the true and predicted values
RR = r2_score(y_val, y_predval)

# Plotting
plt.figure(figsize=(20 , 10))

plt.subplot(1, 2, 1)
plt.scatter(y_val, y_predval,color = "darkorange")
plt.xlabel("Real Data")
plt.ylabel("Predicted")
plt.figure(figsize=(20 , 10))
plt.plot([y_val.min(), y_val.max()], [y_val.min(), y_val.max()], 'k--', lw=4)
print("R^2 = %0.4f" %RR)


plt.subplot(1, 2, 2)
plt.title("Regression Error Characteristic (REC)")
plt.plot(Deviation, Accuracy, "--b",lw =3)
plt.xlabel("Deviation")
plt.ylabel("Accuracy (%)")
plt.text(1.1, 0.07, "AUC = %0.4f" %AUC , fontsize=15)


plt.show()
# Out:
# R^2 = -0.2049
