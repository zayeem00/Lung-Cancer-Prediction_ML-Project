# %%
#importing necessary python packages
import pandas as pd
import numpy as np
import os
from keras.callbacks import ModelCheckpoint
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error 
import warnings 
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', category=DeprecationWarning)
# Out:
# Using TensorFlow backend.

# %%
# Importing the dataset
flux = pd.read_excel('LUAD_flux.xlsx',index_col=0)
genes=pd.read_excel('LUAD_Genes.xlsx',index_col=0)

# %%
flux.shape
# Out:
# (517, 1962)

# %%
flux.head(2)
# Out:
#                   '3DSPHR'  '3HBCOAHLm'    'ABTArm'     'ABTD'   'ACACT1r'  \
# HUG0_SYMBOL
# TCGA-05-4244-01  11.448262   154.187481 -583.764387 -14.237357  125.403072
# TCGA-05-4249-01   9.173955   162.200877 -442.863722  -5.338254  128.134267
#
#                  'ACACT1rm'   'ACACT1x'  'ACOAD9m'  'ACOAO7p'    'ACOATA'  \
# HUG0_SYMBOL
# TCGA-05-4244-01  235.338244  457.654536  74.716367  72.493260 -165.591744
# TCGA-05-4249-01  137.492687  149.939274  75.026103  56.620656  -73.252506
#
#                  ...  '13HTACRitr'  '1513TACRitr'  '1531TACRitr'  \
# HUG0_SYMBOL      ...
# TCGA-05-4244-01  ...     14.770344      14.770344      14.770344
# TCGA-05-4249-01  ...     34.017476      34.017476      34.017476
#
#                  'DEOXFVSitx'    'FVSitx'  'TACRitr'  '13DMTitr'  '15DMTitr'  \
# HUG0_SYMBOL
# TCGA-05-4244-01   -431.370763  431.370763  26.309675   -6.000452   -6.000452
# TCGA-05-4249-01   -219.803538  219.803538  60.593629  -13.819600  -13.819600
#
#                  '31DMTitr'  Overall Survival (Months)
# HUG0_SYMBOL
# TCGA-05-4244-01   -6.000452                       0.00
# TCGA-05-4249-01  -13.819600                      50.03
#
# [2 rows x 1962 columns]

# %%
del flux['Overall Survival (Months)']

# %%
dt = flux.merge(genes,left_index=True,right_index=True)

# %%
dt.head()
# Out:
#                   '3DSPHR'  '3HBCOAHLm'    'ABTArm'     'ABTD'   'ACACT1r'  \
# HUG0_SYMBOL
# TCGA-05-4244-01  11.448262   154.187481 -583.764387 -14.237357  125.403072
# TCGA-05-4249-01   9.173955   162.200877 -442.863722  -5.338254  128.134267
# TCGA-05-4250-01  11.167238    96.659688 -661.410699 -14.973614  185.149045
# TCGA-05-4382-01   9.813735   152.832310 -413.172469  -7.077201  198.790709
# TCGA-05-4384-01  10.017708   146.338416 -483.996897  -7.935740  151.432371
#
#                  'ACACT1rm'   'ACACT1x'  'ACOAD9m'  'ACOAO7p'    'ACOATA'  \
# HUG0_SYMBOL
# TCGA-05-4244-01  235.338244  457.654536  74.716367  72.493260 -165.591744
# TCGA-05-4249-01  137.492687  149.939274  75.026103  56.620656  -73.252506
# TCGA-05-4250-01  192.183642  403.670235  74.716367  16.444642 -176.456428
# TCGA-05-4382-01  137.492687  161.066009  68.272577  57.663478  -83.597986
# TCGA-05-4384-01   58.691049  170.595446  52.965875  55.165456  -87.272646
#
#                  ...    SLTM    SLU7  SLURP1   SMAD2   SMAD3   SMAD4   SMAD5  \
# HUG0_SYMBOL      ...
# TCGA-05-4244-01  ... -1.1877  3.4584 -0.2752 -0.7736 -0.6896 -0.0017  0.1779
# TCGA-05-4249-01  ... -0.5540  0.7962 -0.2752 -0.6214  0.0881  1.3829  2.3203
# TCGA-05-4250-01  ... -1.3805  0.0730 -0.2752 -1.3034  1.0473 -0.3628  0.0526
# TCGA-05-4382-01  ... -0.3885 -1.5611 -0.2752  0.3948 -0.6485  0.5367 -0.9418
# TCGA-05-4384-01  ...  0.4227  0.7651 -0.2752  0.2285 -0.4482  0.5020  0.5863
#
#                   SMAD6   SMAD7  Survival
# HUG0_SYMBOL
# TCGA-05-4244-01 -0.6433  0.7445       0.00
# TCGA-05-4249-01 -0.4918  0.0368      50.03
# TCGA-05-4250-01 -0.8961 -1.1245       3.98
# TCGA-05-4382-01 -0.1446  2.2863      19.94
# TCGA-05-4384-01  0.3185 -0.3951      13.99
#
# [5 rows x 16768 columns]

# %%
dt.shape
# Out:
# (517, 16768)

# %%
X = dt.iloc[:,0:16767].values
y = dt.iloc[:, -1].values

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=0)

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)
X_val = sc_X.fit_transform(X_val)

# %%
sc_y = StandardScaler()
y_train = np.squeeze(sc_y.fit_transform(y_train.reshape(-1, 1)))
y_val = np.squeeze(sc_y.transform(y_val.reshape(-1, 1)))
y_test = np.squeeze(sc_y.transform(y_test.reshape(-1, 1)))

# %%
#Create Deep Neural Network Architecuture
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout

NN_model = Sequential()

# The Input Layer :
NN_model.add(Dense(128, kernel_initializer='normal',input_dim = X_train.shape[1], activation='relu'))

# The Hidden Layers :
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))

# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))

# Compile the network :
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
NN_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               2146304
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 2,311,169
# Trainable params: 2,311,169
# Non-trainable params: 0
# _________________________________________________________________

# %%
NN_model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split = 0.2)
# Out:
# Train on 264 samples, validate on 66 samples
# Epoch 1/100
# 264/264 [==============================] - 0s 1ms/sample - loss: 0.8170 - mean_absolute_error: 0.8170 - val_loss: 0.5512 - val_mean_absolute_error: 0.5512
# Epoch 2/100
# 264/264 [==============================] - 0s 481us/sample - loss: 0.6480 - mean_absolute_error: 0.6480 - val_loss: 0.6750 - val_mean_absolute_error: 0.6750
# Epoch 3/100
# 264/264 [==============================] - 0s 464us/sample - loss: 0.6175 - mean_absolute_error: 0.6175 - val_loss: 0.6439 - val_mean_absolute_error: 0.6439
# Epoch 4/100
# 264/264 [==============================] - 0s 470us/sample - loss: 0.4882 - mean_absolute_error: 0.4882 - val_loss: 0.5845 - val_mean_absolute_error: 0.5845
# Epoch 5/100
# 264/264 [==============================] - 0s 472us/sample - loss: 0.4726 - mean_absolute_error: 0.4726 - val_loss: 0.5561 - val_mean_absolute_error: 0.5561
# Epoch 6/100
# 264/264 [==============================] - 0s 487us/sample - loss: 0.4357 - mean_absolute_error: 0.4357 - val_loss: 0.5229 - val_mean_absolute_error: 0.5229
# Epoch 7/100
# 264/264 [==============================] - 0s 472us/sample - loss: 0.3391 - mean_absolute_error: 0.3391 - val_loss: 0.6628 - val_mean_absolute_error: 0.6628
# Epoch 8/100
# 264/264 [==============================] - 0s 481us/sample - loss: 0.3566 - mean_absolute_error: 0.3566 - val_loss: 0.4612 - val_mean_absolute_error: 0.4612
# Epoch 9/100
# 264/264 [==============================] - 0s 484us/sample - loss: 0.3682 - mean_absolute_error: 0.3682 - val_loss: 0.5424 - val_mean_absolute_error: 0.5424
# Epoch 10/100
# 264/264 [==============================] - 0s 475us/sample - loss: 0.3309 - mean_absolute_error: 0.3309 - val_loss: 0.4936 - val_mean_absolute_error: 0.4936
# Epoch 11/100
# 264/264 [==============================] - 0s 470us/sample - loss: 0.3441 - mean_absolute_error: 0.3441 - val_loss: 0.5585 - val_mean_absolute_error: 0.5585
# Epoch 12/100
# 264/264 [==============================] - 0s 467us/sample - loss: 0.2494 - mean_absolute_error: 0.2494 - val_loss: 0.5473 - val_mean_absolute_error: 0.5473
# Epoch 13/100
# 264/264 [==============================] - 0s 473us/sample - loss: 0.2649 - mean_absolute_error: 0.2649 - val_loss: 0.5605 - val_mean_absolute_error: 0.5605
# Epoch 14/100
# 264/264 [==============================] - 0s 467us/sample - loss: 0.2264 - mean_absolute_error: 0.2264 - val_loss: 0.5237 - val_mean_absolute_error: 0.5237
# Epoch 15/100
# 264/264 [==============================] - 0s 464us/sample - loss: 0.2119 - mean_absolute_error: 0.2119 - val_loss: 0.5038 - val_mean_absolute_error: 0.5038
# Epoch 16/100
# 264/264 [==============================] - 0s 464us/sample - loss: 0.2063 - mean_absolute_error: 0.2063 - val_loss: 0.6181 - val_mean_absolute_error: 0.6181
# Epoch 17/100
# 264/264 [==============================] - 0s 465us/sample - loss: 0.2248 - mean_absolute_error: 0.2248 - val_loss: 0.4757 - val_mean_absolute_error: 0.4757
# Epoch 18/100
# 264/264 [==============================] - 0s 463us/sample - loss: 0.2380 - mean_absolute_error: 0.2380 - val_loss: 0.5160 - val_mean_absolute_error: 0.5160
# Epoch 19/100
# 264/264 [==============================] - 0s 471us/sample - loss: 0.1865 - mean_absolute_error: 0.1865 - val_loss: 0.5011 - val_mean_absolute_error: 0.5011
# Epoch 20/100
# 264/264 [==============================] - 0s 467us/sample - loss: 0.1900 - mean_absolute_error: 0.1900 - val_loss: 0.5047 - val_mean_absolute_error: 0.5047
# Epoch 21/100
# 264/264 [==============================] - 0s 461us/sample - loss: 0.1786 - mean_absolute_error: 0.1786 - val_loss: 0.4824 - val_mean_absolute_error: 0.4824
# Epoch 22/100
# 264/264 [==============================] - 0s 453us/sample - loss: 0.1986 - mean_absolute_error: 0.1986 - val_loss: 0.5182 - val_mean_absolute_error: 0.5182
# Epoch 23/100
# 264/264 [==============================] - 0s 479us/sample - loss: 0.2012 - mean_absolute_error: 0.2012 - val_loss: 0.5162 - val_mean_absolute_error: 0.5162
# Epoch 24/100
# 264/264 [==============================] - 0s 468us/sample - loss: 0.1694 - mean_absolute_error: 0.1694 - val_loss: 0.5422 - val_mean_absolute_error: 0.5422
# Epoch 25/100
# 264/264 [==============================] - 0s 466us/sample - loss: 0.1688 - mean_absolute_error: 0.1688 - val_loss: 0.5014 - val_mean_absolute_error: 0.5014
# Epoch 26/100
# 264/264 [==============================] - 0s 474us/sample - loss: 0.1720 - mean_absolute_error: 0.1720 - val_loss: 0.6011 - val_mean_absolute_error: 0.6011
# Epoch 27/100
# 264/264 [==============================] - 0s 482us/sample - loss: 0.1596 - mean_absolute_error: 0.1596 - val_loss: 0.5130 - val_mean_absolute_error: 0.5130
# Epoch 28/100
# 264/264 [==============================] - 0s 488us/sample - loss: 0.2074 - mean_absolute_error: 0.2074 - val_loss: 0.4963 - val_mean_absolute_error: 0.4963
# Epoch 29/100
# 264/264 [==============================] - 0s 487us/sample - loss: 0.1535 - mean_absolute_error: 0.1535 - val_loss: 0.5304 - val_mean_absolute_error: 0.5304
# Epoch 30/100
# 264/264 [==============================] - 0s 486us/sample - loss: 0.1442 - mean_absolute_error: 0.1442 - val_loss: 0.5422 - val_mean_absolute_error: 0.5422
# Epoch 31/100
# 264/264 [==============================] - 0s 477us/sample - loss: 0.1563 - mean_absolute_error: 0.1563 - val_loss: 0.5443 - val_mean_absolute_error: 0.5443
# Epoch 32/100
# 264/264 [==============================] - 0s 457us/sample - loss: 0.1447 - mean_absolute_error: 0.1447 - val_loss: 0.5248 - val_mean_absolute_error: 0.5248
# Epoch 33/100
# 264/264 [==============================] - 0s 483us/sample - loss: 0.1468 - mean_absolute_error: 0.1468 - val_loss: 0.5228 - val_mean_absolute_error: 0.5228
# Epoch 34/100
# 264/264 [==============================] - 0s 461us/sample - loss: 0.1381 - mean_absolute_error: 0.1381 - val_loss: 0.5452 - val_mean_absolute_error: 0.5452
# Epoch 35/100
# 264/264 [==============================] - 0s 521us/sample - loss: 0.1628 - mean_absolute_error: 0.1628 - val_loss: 0.5062 - val_mean_absolute_error: 0.5062
# Epoch 36/100
# 264/264 [==============================] - 0s 514us/sample - loss: 0.1507 - mean_absolute_error: 0.1507 - val_loss: 0.5174 - val_mean_absolute_error: 0.5174
# Epoch 37/100
# 264/264 [==============================] - 0s 448us/sample - loss: 0.1443 - mean_absolute_error: 0.1443 - val_loss: 0.5257 - val_mean_absolute_error: 0.5257
# Epoch 38/100
# 264/264 [==============================] - 0s 476us/sample - loss: 0.1495 - mean_absolute_error: 0.1495 - val_loss: 0.5135 - val_mean_absolute_error: 0.5135
# Epoch 39/100
# 264/264 [==============================] - 0s 466us/sample - loss: 0.1243 - mean_absolute_error: 0.1243 - val_loss: 0.5187 - val_mean_absolute_error: 0.5187
# Epoch 40/100
# 264/264 [==============================] - 0s 468us/sample - loss: 0.1408 - mean_absolute_error: 0.1408 - val_loss: 0.5256 - val_mean_absolute_error: 0.5256
# Epoch 41/100
# 264/264 [==============================] - 0s 464us/sample - loss: 0.1323 - mean_absolute_error: 0.1323 - val_loss: 0.5001 - val_mean_absolute_error: 0.5001
# Epoch 42/100
# 264/264 [==============================] - 0s 475us/sample - loss: 0.1439 - mean_absolute_error: 0.1439 - val_loss: 0.5365 - val_mean_absolute_error: 0.5365
# Epoch 43/100
# 264/264 [==============================] - 0s 466us/sample - loss: 0.1335 - mean_absolute_error: 0.1335 - val_loss: 0.5028 - val_mean_absolute_error: 0.5028
# Epoch 44/100
# 264/264 [==============================] - 0s 452us/sample - loss: 0.1367 - mean_absolute_error: 0.1367 - val_loss: 0.5479 - val_mean_absolute_error: 0.5479
# Epoch 45/100
# 264/264 [==============================] - 0s 466us/sample - loss: 0.1271 - mean_absolute_error: 0.1271 - val_loss: 0.4787 - val_mean_absolute_error: 0.4787
# Epoch 46/100
# 264/264 [==============================] - 0s 460us/sample - loss: 0.1260 - mean_absolute_error: 0.1260 - val_loss: 0.5488 - val_mean_absolute_error: 0.5488
# Epoch 47/100
# 264/264 [==============================] - 0s 465us/sample - loss: 0.1227 - mean_absolute_error: 0.1227 - val_loss: 0.4943 - val_mean_absolute_error: 0.4943
# Epoch 48/100
# 264/264 [==============================] - 0s 460us/sample - loss: 0.1311 - mean_absolute_error: 0.1311 - val_loss: 0.5188 - val_mean_absolute_error: 0.5188
# Epoch 49/100
# 264/264 [==============================] - 0s 446us/sample - loss: 0.1263 - mean_absolute_error: 0.1263 - val_loss: 0.5450 - val_mean_absolute_error: 0.5450
# Epoch 50/100
# 264/264 [==============================] - 0s 441us/sample - loss: 0.1247 - mean_absolute_error: 0.1247 - val_loss: 0.5006 - val_mean_absolute_error: 0.5006
# Epoch 51/100
# 264/264 [==============================] - 0s 454us/sample - loss: 0.1357 - mean_absolute_error: 0.1357 - val_loss: 0.5399 - val_mean_absolute_error: 0.5399
# Epoch 52/100
# 264/264 [==============================] - 0s 453us/sample - loss: 0.1083 - mean_absolute_error: 0.1083 - val_loss: 0.5448 - val_mean_absolute_error: 0.5448
# Epoch 53/100
# 264/264 [==============================] - 0s 454us/sample - loss: 0.1043 - mean_absolute_error: 0.1043 - val_loss: 0.5353 - val_mean_absolute_error: 0.5353
# Epoch 54/100
# 264/264 [==============================] - 0s 450us/sample - loss: 0.1008 - mean_absolute_error: 0.1008 - val_loss: 0.5382 - val_mean_absolute_error: 0.5382
# Epoch 55/100
# 264/264 [==============================] - 0s 455us/sample - loss: 0.1030 - mean_absolute_error: 0.1030 - val_loss: 0.5403 - val_mean_absolute_error: 0.5403
# Epoch 56/100
# 264/264 [==============================] - 0s 457us/sample - loss: 0.1087 - mean_absolute_error: 0.1087 - val_loss: 0.5122 - val_mean_absolute_error: 0.5122
# Epoch 57/100
# 264/264 [==============================] - 0s 456us/sample - loss: 0.1155 - mean_absolute_error: 0.1155 - val_loss: 0.5432 - val_mean_absolute_error: 0.5432
# Epoch 58/100
# 264/264 [==============================] - 0s 453us/sample - loss: 0.1209 - mean_absolute_error: 0.1209 - val_loss: 0.5428 - val_mean_absolute_error: 0.5428
# Epoch 59/100
# 264/264 [==============================] - 0s 463us/sample - loss: 0.1259 - mean_absolute_error: 0.1259 - val_loss: 0.5430 - val_mean_absolute_error: 0.5430
# Epoch 60/100
# 264/264 [==============================] - 0s 453us/sample - loss: 0.0846 - mean_absolute_error: 0.0846 - val_loss: 0.5419 - val_mean_absolute_error: 0.5419
# Epoch 61/100
# 264/264 [==============================] - 0s 459us/sample - loss: 0.1036 - mean_absolute_error: 0.1036 - val_loss: 0.5369 - val_mean_absolute_error: 0.5369
# Epoch 62/100
# 264/264 [==============================] - 0s 456us/sample - loss: 0.0898 - mean_absolute_error: 0.0898 - val_loss: 0.5170 - val_mean_absolute_error: 0.5170
# Epoch 63/100
# 264/264 [==============================] - 0s 463us/sample - loss: 0.1276 - mean_absolute_error: 0.1276 - val_loss: 0.5995 - val_mean_absolute_error: 0.5995
# Epoch 64/100
# 264/264 [==============================] - 0s 457us/sample - loss: 0.1676 - mean_absolute_error: 0.1676 - val_loss: 0.5344 - val_mean_absolute_error: 0.5344
# Epoch 65/100
# 264/264 [==============================] - 0s 458us/sample - loss: 0.1406 - mean_absolute_error: 0.1406 - val_loss: 0.5639 - val_mean_absolute_error: 0.5639
# Epoch 66/100
# 264/264 [==============================] - 0s 458us/sample - loss: 0.1347 - mean_absolute_error: 0.1347 - val_loss: 0.5293 - val_mean_absolute_error: 0.5293
# Epoch 67/100
# 264/264 [==============================] - 0s 459us/sample - loss: 0.1120 - mean_absolute_error: 0.1120 - val_loss: 0.5446 - val_mean_absolute_error: 0.5446
# Epoch 68/100
# 264/264 [==============================] - 0s 449us/sample - loss: 0.1050 - mean_absolute_error: 0.1050 - val_loss: 0.5338 - val_mean_absolute_error: 0.5338
# Epoch 69/100
# 264/264 [==============================] - 0s 462us/sample - loss: 0.1219 - mean_absolute_error: 0.1219 - val_loss: 0.6000 - val_mean_absolute_error: 0.6000
# Epoch 70/100
# 264/264 [==============================] - 0s 456us/sample - loss: 0.1114 - mean_absolute_error: 0.1114 - val_loss: 0.5414 - val_mean_absolute_error: 0.5414
# Epoch 71/100
# 264/264 [==============================] - 0s 446us/sample - loss: 0.1028 - mean_absolute_error: 0.1028 - val_loss: 0.5811 - val_mean_absolute_error: 0.5811
# Epoch 72/100
# 264/264 [==============================] - 0s 457us/sample - loss: 0.1023 - mean_absolute_error: 0.1023 - val_loss: 0.5523 - val_mean_absolute_error: 0.5523
# Epoch 73/100
# 264/264 [==============================] - 0s 474us/sample - loss: 0.1068 - mean_absolute_error: 0.1068 - val_loss: 0.5841 - val_mean_absolute_error: 0.5841
# Epoch 74/100
# 264/264 [==============================] - 0s 470us/sample - loss: 0.1148 - mean_absolute_error: 0.1148 - val_loss: 0.5643 - val_mean_absolute_error: 0.5643
# Epoch 75/100
# 264/264 [==============================] - 0s 479us/sample - loss: 0.0909 - mean_absolute_error: 0.0909 - val_loss: 0.5582 - val_mean_absolute_error: 0.5582
# Epoch 76/100
# 264/264 [==============================] - 0s 467us/sample - loss: 0.0871 - mean_absolute_error: 0.0871 - val_loss: 0.5659 - val_mean_absolute_error: 0.5659
# Epoch 77/100
# 264/264 [==============================] - 0s 471us/sample - loss: 0.0816 - mean_absolute_error: 0.0816 - val_loss: 0.5279 - val_mean_absolute_error: 0.5279
# Epoch 78/100
# 264/264 [==============================] - 0s 449us/sample - loss: 0.0856 - mean_absolute_error: 0.0856 - val_loss: 0.5714 - val_mean_absolute_error: 0.5714
# Epoch 79/100
# 264/264 [==============================] - 0s 504us/sample - loss: 0.0926 - mean_absolute_error: 0.0926 - val_loss: 0.5408 - val_mean_absolute_error: 0.5408
# Epoch 80/100
# 264/264 [==============================] - 0s 525us/sample - loss: 0.0829 - mean_absolute_error: 0.0829 - val_loss: 0.5585 - val_mean_absolute_error: 0.5585
# Epoch 81/100
# 264/264 [==============================] - 0s 551us/sample - loss: 0.0727 - mean_absolute_error: 0.0727 - val_loss: 0.5854 - val_mean_absolute_error: 0.5854
# Epoch 82/100
# 264/264 [==============================] - 0s 494us/sample - loss: 0.0779 - mean_absolute_error: 0.0779 - val_loss: 0.5865 - val_mean_absolute_error: 0.5865
# Epoch 83/100
# 264/264 [==============================] - 0s 497us/sample - loss: 0.0750 - mean_absolute_error: 0.0750 - val_loss: 0.5866 - val_mean_absolute_error: 0.5866
# Epoch 84/100
# 264/264 [==============================] - 0s 495us/sample - loss: 0.0752 - mean_absolute_error: 0.0752 - val_loss: 0.5893 - val_mean_absolute_error: 0.5893
# Epoch 85/100
# 264/264 [==============================] - 0s 502us/sample - loss: 0.0901 - mean_absolute_error: 0.0901 - val_loss: 0.5820 - val_mean_absolute_error: 0.5820
# Epoch 86/100
# 264/264 [==============================] - 0s 499us/sample - loss: 0.0738 - mean_absolute_error: 0.0738 - val_loss: 0.5582 - val_mean_absolute_error: 0.5582
# Epoch 87/100
# 264/264 [==============================] - 0s 515us/sample - loss: 0.0880 - mean_absolute_error: 0.0880 - val_loss: 0.6019 - val_mean_absolute_error: 0.6019
# Epoch 88/100
# 264/264 [==============================] - 0s 512us/sample - loss: 0.0772 - mean_absolute_error: 0.0772 - val_loss: 0.5365 - val_mean_absolute_error: 0.5365
# Epoch 89/100
# 264/264 [==============================] - 0s 503us/sample - loss: 0.1106 - mean_absolute_error: 0.1106 - val_loss: 0.5397 - val_mean_absolute_error: 0.5397
# Epoch 90/100
# 264/264 [==============================] - 0s 503us/sample - loss: 0.0874 - mean_absolute_error: 0.0874 - val_loss: 0.5736 - val_mean_absolute_error: 0.5736
# Epoch 91/100
# 264/264 [==============================] - 0s 481us/sample - loss: 0.0894 - mean_absolute_error: 0.0894 - val_loss: 0.5791 - val_mean_absolute_error: 0.5791
# Epoch 92/100
# 264/264 [==============================] - 0s 505us/sample - loss: 0.0728 - mean_absolute_error: 0.0728 - val_loss: 0.5584 - val_mean_absolute_error: 0.5584
# Epoch 93/100
# 264/264 [==============================] - 0s 501us/sample - loss: 0.0699 - mean_absolute_error: 0.0699 - val_loss: 0.5744 - val_mean_absolute_error: 0.5744
# Epoch 94/100
# 264/264 [==============================] - 0s 467us/sample - loss: 0.0775 - mean_absolute_error: 0.0775 - val_loss: 0.5399 - val_mean_absolute_error: 0.5399
# Epoch 95/100
# 264/264 [==============================] - 0s 497us/sample - loss: 0.0801 - mean_absolute_error: 0.0801 - val_loss: 0.5947 - val_mean_absolute_error: 0.5947
# Epoch 96/100
# 264/264 [==============================] - 0s 492us/sample - loss: 0.0871 - mean_absolute_error: 0.0871 - val_loss: 0.5186 - val_mean_absolute_error: 0.5186
# Epoch 97/100
# 264/264 [==============================] - 0s 1ms/sample - loss: 0.0905 - mean_absolute_error: 0.0905 - val_loss: 0.6156 - val_mean_absolute_error: 0.6156
# Epoch 98/100
# 264/264 [==============================] - 0s 480us/sample - loss: 0.1287 - mean_absolute_error: 0.1287 - val_loss: 0.5148 - val_mean_absolute_error: 0.5148
# Epoch 99/100
# 264/264 [==============================] - 0s 472us/sample - loss: 0.1192 - mean_absolute_error: 0.1192 - val_loss: 0.5676 - val_mean_absolute_error: 0.5676
# Epoch 100/100
# 264/264 [==============================] - 0s 488us/sample - loss: 0.0896 - mean_absolute_error: 0.0896 - val_loss: 0.5219 - val_mean_absolute_error: 0.5219

# %%
#Predicting the Validation set results
y_predval = NN_model.predict(X_val)

# %%
# Print result of MAE
from sklearn import metrics
print(metrics.mean_absolute_error(y_val, y_predval))

# Print result of MSE
print(metrics.mean_squared_error(y_val, y_predval))

# Print result of RMSE
print(np.sqrt(metrics.mean_squared_error(y_val, y_predval)))

from sklearn.metrics import r2_score
accuracy=r2_score(y_val,y_predval)

print('R2 Score')
print(accuracy)
# Out:
# 0.6219113474260224
# 0.7502668713969102
# 0.8661794683533605
# R2 Score
# -0.07694155892980037

# %%
# Visualising the Random Forest Regression Results
# Loading Packages
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import r2_score
#from sklearn import linear_model
from sklearn import datasets
from scipy.integrate import simps

# Function for Regression Error Characteritic Curve

def REC(y_val , y_predval):
    
    # initilizing the lists
    Accuracy = []
    
    # initializing the values for Epsilon
    Begin_Range = 0
    End_Range = 1.5
    Interval_Size = 0.01
    
    # List of epsilons
    Epsilon = np.arange(Begin_Range , End_Range , Interval_Size)
    
    # Main Loops
    for i in range(len(Epsilon)):
        count = 0.0
        for j in range(len(y_val)):
            if np.linalg.norm(y_val[j] - y_predval[j]) / np.sqrt( np.linalg.norm(y_val[j]) **2 + np.linalg.norm(y_predval[j])**2 ) < Epsilon[i]:
                count = count + 1
        
        Accuracy.append(count/len(y_val))
    
    # Calculating Area Under Curve using Simpson's rule
    AUC = simps(Accuracy , Epsilon ) / End_Range
        
    # returning epsilon , accuracy , area under curve    
    return Epsilon , Accuracy , AUC

# finding the deviation and accuracy, and area under curve for plotting
Deviation, Accuracy, AUC = REC(y_val, y_predval)

# Calculating R^2 of the true and predicted values
RR = r2_score(y_val, y_predval)

# Plotting
plt.figure(figsize=(20 , 10))

plt.subplot(1, 2, 1)
plt.scatter(y_val, y_predval,color = "darkorange")
plt.xlabel("Real Data")
plt.ylabel("Predicted")
plt.figure(figsize=(20 , 10))
plt.plot([y_val.min(), y_val.max()], [y_val.min(), y_val.max()], 'k--', lw=4)
print("R^2 = %0.4f" %RR)


plt.subplot(1, 2, 2)
plt.title("Regression Error Characteristic (REC)")
plt.plot(Deviation, Accuracy, "--b",lw =3)
plt.xlabel("Deviation")
plt.ylabel("Accuracy (%)")
plt.text(1.1, 0.07, "AUC = %0.4f" %AUC , fontsize=15)


plt.show()
# Out:
# R^2 = -0.0769
