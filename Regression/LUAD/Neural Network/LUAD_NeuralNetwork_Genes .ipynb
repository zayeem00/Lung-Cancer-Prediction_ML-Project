# %%
#importing necessary python packages
import pandas as pd
import numpy as np
import os
from keras.callbacks import ModelCheckpoint
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error 
import warnings 
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', category=DeprecationWarning)
# Out:
# Using TensorFlow backend.

# %%
# Importing the dataset
dt = pd.read_excel('LUAD_Genes.xlsx',index_col=0)

# %%
dt.shape
# Out:
# (517, 14807)

# %%
dt.head(2)
# Out:
#                  UBE2Q2P2    SSX9  CXORF67  EFCAB8  SDR16C6P  EFCAB12    A1BG  \
# Hugo_Symbol
# TCGA-05-4244-01   -0.4238 -0.1379  -0.1805  0.4529   -0.3317  -0.1012 -0.6977
# TCGA-05-4249-01   -0.3291 -0.1379  -0.1805 -0.0869   -0.3317  -0.1661 -0.1483
#
#                    A1CF  RBFOX1   GGACT  ...    SLTM    SLU7  SLURP1   SMAD2  \
# Hugo_Symbol                              ...
# TCGA-05-4244-01 -0.1476  -0.224  0.3832  ... -1.1877  3.4584 -0.2752 -0.7736
# TCGA-05-4249-01 -0.1371  -0.226 -0.5346  ... -0.5540  0.7962 -0.2752 -0.6214
#
#                   SMAD3   SMAD4   SMAD5   SMAD6   SMAD7  Survival
# Hugo_Symbol
# TCGA-05-4244-01 -0.6896 -0.0017  0.1779 -0.6433  0.7445       0.00
# TCGA-05-4249-01  0.0881  1.3829  2.3203 -0.4918  0.0368      50.03
#
# [2 rows x 14807 columns]

# %%
X = dt.iloc[:,0:14806].values
y = dt.iloc[:, -1].values

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=0)

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)
X_val = sc_X.fit_transform(X_val)

# %%
sc_y = StandardScaler()
y_train = np.squeeze(sc_y.fit_transform(y_train.reshape(-1, 1)))
y_val = np.squeeze(sc_y.transform(y_val.reshape(-1, 1)))
y_test = np.squeeze(sc_y.transform(y_test.reshape(-1, 1)))

# %%
#Create Deep Neural Network Architecuture
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout

NN_model = Sequential()

# The Input Layer :
NN_model.add(Dense(128, kernel_initializer='normal',input_dim = X_train.shape[1], activation='relu'))

# The Hidden Layers :
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))

# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))

# Compile the network :
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
NN_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               1895296
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 2,060,161
# Trainable params: 2,060,161
# Non-trainable params: 0
# _________________________________________________________________

# %%
NN_model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split = 0.2)
# Out:
# Train on 264 samples, validate on 66 samples
# Epoch 1/100
# 264/264 [==============================] - 0s 1ms/sample - loss: 0.8651 - mean_absolute_error: 0.8651 - val_loss: 0.7924 - val_mean_absolute_error: 0.7924
# Epoch 2/100
# 264/264 [==============================] - 0s 461us/sample - loss: 0.8133 - mean_absolute_error: 0.8133 - val_loss: 0.6410 - val_mean_absolute_error: 0.6410
# Epoch 3/100
# 264/264 [==============================] - 0s 461us/sample - loss: 0.6140 - mean_absolute_error: 0.6140 - val_loss: 0.4892 - val_mean_absolute_error: 0.4892
# Epoch 4/100
# 264/264 [==============================] - 0s 470us/sample - loss: 0.5190 - mean_absolute_error: 0.5190 - val_loss: 0.4979 - val_mean_absolute_error: 0.4979
# Epoch 5/100
# 264/264 [==============================] - 0s 476us/sample - loss: 0.4692 - mean_absolute_error: 0.4692 - val_loss: 0.5636 - val_mean_absolute_error: 0.5636
# Epoch 6/100
# 264/264 [==============================] - 0s 500us/sample - loss: 0.4071 - mean_absolute_error: 0.4071 - val_loss: 0.5190 - val_mean_absolute_error: 0.5190
# Epoch 7/100
# 264/264 [==============================] - 0s 474us/sample - loss: 0.3655 - mean_absolute_error: 0.3655 - val_loss: 0.5776 - val_mean_absolute_error: 0.5776
# Epoch 8/100
# 264/264 [==============================] - 0s 471us/sample - loss: 0.3256 - mean_absolute_error: 0.3256 - val_loss: 0.4926 - val_mean_absolute_error: 0.4926
# Epoch 9/100
# 264/264 [==============================] - 0s 469us/sample - loss: 0.2648 - mean_absolute_error: 0.2648 - val_loss: 0.5310 - val_mean_absolute_error: 0.5310
# Epoch 10/100
# 264/264 [==============================] - 0s 467us/sample - loss: 0.2612 - mean_absolute_error: 0.2612 - val_loss: 0.5331 - val_mean_absolute_error: 0.5331
# Epoch 11/100
# 264/264 [==============================] - 0s 471us/sample - loss: 0.2642 - mean_absolute_error: 0.2642 - val_loss: 0.6241 - val_mean_absolute_error: 0.6241
# Epoch 12/100
# 264/264 [==============================] - 0s 461us/sample - loss: 0.2821 - mean_absolute_error: 0.2821 - val_loss: 0.5165 - val_mean_absolute_error: 0.5165
# Epoch 13/100
# 264/264 [==============================] - 0s 468us/sample - loss: 0.2384 - mean_absolute_error: 0.2384 - val_loss: 0.6255 - val_mean_absolute_error: 0.6255
# Epoch 14/100
# 264/264 [==============================] - 0s 469us/sample - loss: 0.2376 - mean_absolute_error: 0.2376 - val_loss: 0.5502 - val_mean_absolute_error: 0.5502
# Epoch 15/100
# 264/264 [==============================] - 0s 464us/sample - loss: 0.2201 - mean_absolute_error: 0.2201 - val_loss: 0.5707 - val_mean_absolute_error: 0.5707
# Epoch 16/100
# 264/264 [==============================] - 0s 481us/sample - loss: 0.1947 - mean_absolute_error: 0.1947 - val_loss: 0.5460 - val_mean_absolute_error: 0.5460
# Epoch 17/100
# 264/264 [==============================] - 0s 472us/sample - loss: 0.2113 - mean_absolute_error: 0.2113 - val_loss: 0.5370 - val_mean_absolute_error: 0.5370
# Epoch 18/100
# 264/264 [==============================] - 0s 464us/sample - loss: 0.2246 - mean_absolute_error: 0.2246 - val_loss: 0.5182 - val_mean_absolute_error: 0.5182
# Epoch 19/100
# 264/264 [==============================] - 0s 475us/sample - loss: 0.1944 - mean_absolute_error: 0.1944 - val_loss: 0.5865 - val_mean_absolute_error: 0.5865
# Epoch 20/100
# 264/264 [==============================] - 0s 464us/sample - loss: 0.2020 - mean_absolute_error: 0.2020 - val_loss: 0.5467 - val_mean_absolute_error: 0.5467
# Epoch 21/100
# 264/264 [==============================] - 0s 525us/sample - loss: 0.1948 - mean_absolute_error: 0.1948 - val_loss: 0.5452 - val_mean_absolute_error: 0.5452
# Epoch 22/100
# 264/264 [==============================] - 0s 475us/sample - loss: 0.1942 - mean_absolute_error: 0.1942 - val_loss: 0.5888 - val_mean_absolute_error: 0.5888
# Epoch 23/100
# 264/264 [==============================] - 0s 494us/sample - loss: 0.1974 - mean_absolute_error: 0.1974 - val_loss: 0.5345 - val_mean_absolute_error: 0.5345
# Epoch 24/100
# 264/264 [==============================] - 0s 486us/sample - loss: 0.1761 - mean_absolute_error: 0.1761 - val_loss: 0.5753 - val_mean_absolute_error: 0.5753
# Epoch 25/100
# 264/264 [==============================] - 0s 467us/sample - loss: 0.1563 - mean_absolute_error: 0.1563 - val_loss: 0.5420 - val_mean_absolute_error: 0.5420
# Epoch 26/100
# 264/264 [==============================] - 0s 464us/sample - loss: 0.1577 - mean_absolute_error: 0.1577 - val_loss: 0.5598 - val_mean_absolute_error: 0.5598
# Epoch 27/100
# 264/264 [==============================] - 0s 471us/sample - loss: 0.1149 - mean_absolute_error: 0.1149 - val_loss: 0.5582 - val_mean_absolute_error: 0.5582
# Epoch 28/100
# 264/264 [==============================] - 0s 475us/sample - loss: 0.1345 - mean_absolute_error: 0.1345 - val_loss: 0.5263 - val_mean_absolute_error: 0.5263
# Epoch 29/100
# 264/264 [==============================] - 0s 501us/sample - loss: 0.1416 - mean_absolute_error: 0.1416 - val_loss: 0.5447 - val_mean_absolute_error: 0.5447
# Epoch 30/100
# 264/264 [==============================] - 0s 473us/sample - loss: 0.1316 - mean_absolute_error: 0.1316 - val_loss: 0.5222 - val_mean_absolute_error: 0.5222
# Epoch 31/100
# 264/264 [==============================] - 0s 505us/sample - loss: 0.1142 - mean_absolute_error: 0.1142 - val_loss: 0.5327 - val_mean_absolute_error: 0.5327
# Epoch 32/100
# 264/264 [==============================] - 0s 484us/sample - loss: 0.1351 - mean_absolute_error: 0.1351 - val_loss: 0.5339 - val_mean_absolute_error: 0.5339
# Epoch 33/100
# 264/264 [==============================] - 0s 460us/sample - loss: 0.1026 - mean_absolute_error: 0.1026 - val_loss: 0.5278 - val_mean_absolute_error: 0.5278
# Epoch 34/100
# 264/264 [==============================] - 0s 527us/sample - loss: 0.1169 - mean_absolute_error: 0.1169 - val_loss: 0.4832 - val_mean_absolute_error: 0.4832
# Epoch 35/100
# 264/264 [==============================] - 0s 524us/sample - loss: 0.1213 - mean_absolute_error: 0.1213 - val_loss: 0.5339 - val_mean_absolute_error: 0.5339
# Epoch 36/100
# 264/264 [==============================] - 0s 487us/sample - loss: 0.1242 - mean_absolute_error: 0.1242 - val_loss: 0.4967 - val_mean_absolute_error: 0.4967
# Epoch 37/100
# 264/264 [==============================] - 0s 527us/sample - loss: 0.1353 - mean_absolute_error: 0.1353 - val_loss: 0.5371 - val_mean_absolute_error: 0.5371
# Epoch 38/100
# 264/264 [==============================] - 0s 486us/sample - loss: 0.1131 - mean_absolute_error: 0.1131 - val_loss: 0.5484 - val_mean_absolute_error: 0.5484
# Epoch 39/100
# 264/264 [==============================] - 0s 487us/sample - loss: 0.1173 - mean_absolute_error: 0.1173 - val_loss: 0.5161 - val_mean_absolute_error: 0.5161
# Epoch 40/100
# 264/264 [==============================] - 0s 485us/sample - loss: 0.1218 - mean_absolute_error: 0.1218 - val_loss: 0.5706 - val_mean_absolute_error: 0.5706
# Epoch 41/100
# 264/264 [==============================] - 0s 500us/sample - loss: 0.1139 - mean_absolute_error: 0.1139 - val_loss: 0.5010 - val_mean_absolute_error: 0.5010
# Epoch 42/100
# 264/264 [==============================] - 0s 504us/sample - loss: 0.1180 - mean_absolute_error: 0.1180 - val_loss: 0.5560 - val_mean_absolute_error: 0.5560
# Epoch 43/100
# 264/264 [==============================] - 0s 505us/sample - loss: 0.1079 - mean_absolute_error: 0.1079 - val_loss: 0.5082 - val_mean_absolute_error: 0.5082
# Epoch 44/100
# 264/264 [==============================] - 0s 521us/sample - loss: 0.1289 - mean_absolute_error: 0.1289 - val_loss: 0.5429 - val_mean_absolute_error: 0.5429
# Epoch 45/100
# 264/264 [==============================] - 0s 472us/sample - loss: 0.1047 - mean_absolute_error: 0.1047 - val_loss: 0.5400 - val_mean_absolute_error: 0.5400
# Epoch 46/100
# 264/264 [==============================] - 0s 505us/sample - loss: 0.1125 - mean_absolute_error: 0.1125 - val_loss: 0.5183 - val_mean_absolute_error: 0.5183
# Epoch 47/100
# 264/264 [==============================] - 0s 474us/sample - loss: 0.1201 - mean_absolute_error: 0.1201 - val_loss: 0.5308 - val_mean_absolute_error: 0.5308
# Epoch 48/100
# 264/264 [==============================] - 0s 474us/sample - loss: 0.1179 - mean_absolute_error: 0.1179 - val_loss: 0.5007 - val_mean_absolute_error: 0.5007
# Epoch 49/100
# 264/264 [==============================] - 0s 487us/sample - loss: 0.1164 - mean_absolute_error: 0.1164 - val_loss: 0.5492 - val_mean_absolute_error: 0.5492
# Epoch 50/100
# 264/264 [==============================] - 0s 479us/sample - loss: 0.0987 - mean_absolute_error: 0.0987 - val_loss: 0.5555 - val_mean_absolute_error: 0.5555
# Epoch 51/100
# 264/264 [==============================] - 0s 504us/sample - loss: 0.1128 - mean_absolute_error: 0.1128 - val_loss: 0.5577 - val_mean_absolute_error: 0.5577
# Epoch 52/100
# 264/264 [==============================] - 0s 516us/sample - loss: 0.1028 - mean_absolute_error: 0.1028 - val_loss: 0.5340 - val_mean_absolute_error: 0.5340
# Epoch 53/100
# 264/264 [==============================] - 0s 509us/sample - loss: 0.1021 - mean_absolute_error: 0.1021 - val_loss: 0.5747 - val_mean_absolute_error: 0.5747
# Epoch 54/100
# 264/264 [==============================] - 0s 513us/sample - loss: 0.1022 - mean_absolute_error: 0.1022 - val_loss: 0.5266 - val_mean_absolute_error: 0.5266
# Epoch 55/100
# 264/264 [==============================] - 0s 523us/sample - loss: 0.0959 - mean_absolute_error: 0.0959 - val_loss: 0.5346 - val_mean_absolute_error: 0.5346
# Epoch 56/100
# 264/264 [==============================] - 0s 512us/sample - loss: 0.1054 - mean_absolute_error: 0.1054 - val_loss: 0.5249 - val_mean_absolute_error: 0.5249
# Epoch 57/100
# 264/264 [==============================] - 0s 509us/sample - loss: 0.0953 - mean_absolute_error: 0.0953 - val_loss: 0.5310 - val_mean_absolute_error: 0.5310
# Epoch 58/100
# 264/264 [==============================] - 0s 485us/sample - loss: 0.1157 - mean_absolute_error: 0.1157 - val_loss: 0.5392 - val_mean_absolute_error: 0.5392
# Epoch 59/100
# 264/264 [==============================] - 0s 463us/sample - loss: 0.0879 - mean_absolute_error: 0.0879 - val_loss: 0.5453 - val_mean_absolute_error: 0.5453
# Epoch 60/100
# 264/264 [==============================] - 0s 456us/sample - loss: 0.1104 - mean_absolute_error: 0.1104 - val_loss: 0.5441 - val_mean_absolute_error: 0.5441
# Epoch 61/100
# 264/264 [==============================] - 0s 456us/sample - loss: 0.1043 - mean_absolute_error: 0.1043 - val_loss: 0.5295 - val_mean_absolute_error: 0.5295
# Epoch 62/100
# 264/264 [==============================] - 0s 471us/sample - loss: 0.1031 - mean_absolute_error: 0.1031 - val_loss: 0.5409 - val_mean_absolute_error: 0.5409
# Epoch 63/100
# 264/264 [==============================] - 0s 490us/sample - loss: 0.1041 - mean_absolute_error: 0.1041 - val_loss: 0.5288 - val_mean_absolute_error: 0.5288
# Epoch 64/100
# 264/264 [==============================] - 0s 473us/sample - loss: 0.0868 - mean_absolute_error: 0.0868 - val_loss: 0.5396 - val_mean_absolute_error: 0.5396
# Epoch 65/100
# 264/264 [==============================] - 0s 449us/sample - loss: 0.0803 - mean_absolute_error: 0.0803 - val_loss: 0.5444 - val_mean_absolute_error: 0.5444
# Epoch 66/100
# 264/264 [==============================] - 0s 455us/sample - loss: 0.0941 - mean_absolute_error: 0.0941 - val_loss: 0.5546 - val_mean_absolute_error: 0.5546
# Epoch 67/100
# 264/264 [==============================] - 0s 511us/sample - loss: 0.0887 - mean_absolute_error: 0.0887 - val_loss: 0.5387 - val_mean_absolute_error: 0.5387
# Epoch 68/100
# 264/264 [==============================] - 0s 535us/sample - loss: 0.1012 - mean_absolute_error: 0.1012 - val_loss: 0.5332 - val_mean_absolute_error: 0.5332
# Epoch 69/100
# 264/264 [==============================] - 0s 462us/sample - loss: 0.0892 - mean_absolute_error: 0.0892 - val_loss: 0.5343 - val_mean_absolute_error: 0.5343
# Epoch 70/100
# 264/264 [==============================] - 0s 441us/sample - loss: 0.0970 - mean_absolute_error: 0.0970 - val_loss: 0.5243 - val_mean_absolute_error: 0.5243
# Epoch 71/100
# 264/264 [==============================] - 0s 442us/sample - loss: 0.0947 - mean_absolute_error: 0.0947 - val_loss: 0.5726 - val_mean_absolute_error: 0.5726
# Epoch 72/100
# 264/264 [==============================] - 0s 479us/sample - loss: 0.1207 - mean_absolute_error: 0.1207 - val_loss: 0.5104 - val_mean_absolute_error: 0.5104
# Epoch 73/100
# 264/264 [==============================] - 0s 492us/sample - loss: 0.1202 - mean_absolute_error: 0.1202 - val_loss: 0.5465 - val_mean_absolute_error: 0.5465
# Epoch 74/100
# 264/264 [==============================] - 0s 464us/sample - loss: 0.1007 - mean_absolute_error: 0.1007 - val_loss: 0.5171 - val_mean_absolute_error: 0.5171
# Epoch 75/100
# 264/264 [==============================] - 0s 458us/sample - loss: 0.1240 - mean_absolute_error: 0.1240 - val_loss: 0.5330 - val_mean_absolute_error: 0.5330
# Epoch 76/100
# 264/264 [==============================] - 0s 458us/sample - loss: 0.1055 - mean_absolute_error: 0.1055 - val_loss: 0.5452 - val_mean_absolute_error: 0.5452
# Epoch 77/100
# 264/264 [==============================] - 0s 456us/sample - loss: 0.1003 - mean_absolute_error: 0.1003 - val_loss: 0.5466 - val_mean_absolute_error: 0.5466
# Epoch 78/100
# 264/264 [==============================] - 0s 490us/sample - loss: 0.0830 - mean_absolute_error: 0.0830 - val_loss: 0.5200 - val_mean_absolute_error: 0.5200
# Epoch 79/100
# 264/264 [==============================] - 0s 535us/sample - loss: 0.0910 - mean_absolute_error: 0.0910 - val_loss: 0.5422 - val_mean_absolute_error: 0.5422
# Epoch 80/100
# 264/264 [==============================] - 0s 464us/sample - loss: 0.0777 - mean_absolute_error: 0.0777 - val_loss: 0.5214 - val_mean_absolute_error: 0.5214
# Epoch 81/100
# 264/264 [==============================] - 0s 460us/sample - loss: 0.0775 - mean_absolute_error: 0.0775 - val_loss: 0.5438 - val_mean_absolute_error: 0.5438
# Epoch 82/100
# 264/264 [==============================] - 0s 459us/sample - loss: 0.0992 - mean_absolute_error: 0.0992 - val_loss: 0.5371 - val_mean_absolute_error: 0.5371
# Epoch 83/100
# 264/264 [==============================] - 0s 493us/sample - loss: 0.0862 - mean_absolute_error: 0.0862 - val_loss: 0.5554 - val_mean_absolute_error: 0.5554
# Epoch 84/100
# 264/264 [==============================] - 0s 506us/sample - loss: 0.0781 - mean_absolute_error: 0.0781 - val_loss: 0.5422 - val_mean_absolute_error: 0.5422
# Epoch 85/100
# 264/264 [==============================] - 0s 499us/sample - loss: 0.0825 - mean_absolute_error: 0.0825 - val_loss: 0.5578 - val_mean_absolute_error: 0.5578
# Epoch 86/100
# 264/264 [==============================] - 0s 498us/sample - loss: 0.0814 - mean_absolute_error: 0.0814 - val_loss: 0.5483 - val_mean_absolute_error: 0.5483
# Epoch 87/100
# 264/264 [==============================] - 0s 481us/sample - loss: 0.0955 - mean_absolute_error: 0.0955 - val_loss: 0.5748 - val_mean_absolute_error: 0.5748
# Epoch 88/100
# 264/264 [==============================] - 0s 473us/sample - loss: 0.0947 - mean_absolute_error: 0.0947 - val_loss: 0.5354 - val_mean_absolute_error: 0.5354
# Epoch 89/100
# 264/264 [==============================] - 0s 492us/sample - loss: 0.0922 - mean_absolute_error: 0.0922 - val_loss: 0.5626 - val_mean_absolute_error: 0.5626
# Epoch 90/100
# 264/264 [==============================] - 0s 512us/sample - loss: 0.0789 - mean_absolute_error: 0.0789 - val_loss: 0.5193 - val_mean_absolute_error: 0.5193
# Epoch 91/100
# 264/264 [==============================] - 0s 514us/sample - loss: 0.0917 - mean_absolute_error: 0.0917 - val_loss: 0.5563 - val_mean_absolute_error: 0.5563
# Epoch 92/100
# 264/264 [==============================] - 0s 469us/sample - loss: 0.0828 - mean_absolute_error: 0.0828 - val_loss: 0.5399 - val_mean_absolute_error: 0.5399
# Epoch 93/100
# 264/264 [==============================] - 0s 482us/sample - loss: 0.0969 - mean_absolute_error: 0.0969 - val_loss: 0.5708 - val_mean_absolute_error: 0.5708
# Epoch 94/100
# 264/264 [==============================] - 0s 478us/sample - loss: 0.0977 - mean_absolute_error: 0.0977 - val_loss: 0.5622 - val_mean_absolute_error: 0.5622
# Epoch 95/100
# 264/264 [==============================] - 0s 491us/sample - loss: 0.0805 - mean_absolute_error: 0.0805 - val_loss: 0.5464 - val_mean_absolute_error: 0.5464
# Epoch 96/100
# 264/264 [==============================] - 0s 485us/sample - loss: 0.0753 - mean_absolute_error: 0.0753 - val_loss: 0.5418 - val_mean_absolute_error: 0.5418
# Epoch 97/100
# 264/264 [==============================] - 0s 502us/sample - loss: 0.0742 - mean_absolute_error: 0.0742 - val_loss: 0.5376 - val_mean_absolute_error: 0.5376
# Epoch 98/100
# 264/264 [==============================] - 0s 499us/sample - loss: 0.0617 - mean_absolute_error: 0.0617 - val_loss: 0.5377 - val_mean_absolute_error: 0.5377
# Epoch 99/100
# 264/264 [==============================] - 0s 481us/sample - loss: 0.0640 - mean_absolute_error: 0.0640 - val_loss: 0.5314 - val_mean_absolute_error: 0.5314
# Epoch 100/100
# 264/264 [==============================] - 0s 473us/sample - loss: 0.0666 - mean_absolute_error: 0.0666 - val_loss: 0.5514 - val_mean_absolute_error: 0.5514

# %%
#Predicting the Validation set results
y_predval = NN_model.predict(X_val)

# %%
# Print result of MAE
from sklearn import metrics
print(metrics.mean_absolute_error(y_val, y_predval))

# Print result of MSE
print(metrics.mean_squared_error(y_val, y_predval))

# Print result of RMSE
print(np.sqrt(metrics.mean_squared_error(y_val, y_predval)))

from sklearn.metrics import r2_score
accuracy=r2_score(y_val,y_predval)

print('R2 Score')
print(accuracy)
# Out:
# 0.6798746345365216
# 0.8510468497834993
# 0.9225220050402588
# R2 Score
# -0.22160228056140707

# %%
# Visualising the Random Forest Regression Results
# Loading Packages
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import r2_score
#from sklearn import linear_model
from sklearn import datasets
from scipy.integrate import simps

# Function for Regression Error Characteritic Curve

def REC(y_val , y_predval):
    
    # initilizing the lists
    Accuracy = []
    
    # initializing the values for Epsilon
    Begin_Range = 0
    End_Range = 1.5
    Interval_Size = 0.01
    
    # List of epsilons
    Epsilon = np.arange(Begin_Range , End_Range , Interval_Size)
    
    # Main Loops
    for i in range(len(Epsilon)):
        count = 0.0
        for j in range(len(y_val)):
            if np.linalg.norm(y_val[j] - y_predval[j]) / np.sqrt( np.linalg.norm(y_val[j]) **2 + np.linalg.norm(y_predval[j])**2 ) < Epsilon[i]:
                count = count + 1
        
        Accuracy.append(count/len(y_val))
    
    # Calculating Area Under Curve using Simpson's rule
    AUC = simps(Accuracy , Epsilon ) / End_Range
        
    # returning epsilon , accuracy , area under curve    
    return Epsilon , Accuracy , AUC

# finding the deviation and accuracy, and area under curve for plotting
Deviation, Accuracy, AUC = REC(y_val, y_predval)

# Calculating R^2 of the true and predicted values
RR = r2_score(y_val, y_predval)

# Plotting
plt.figure(figsize=(20 , 10))

plt.subplot(1, 2, 1)
plt.scatter(y_val, y_predval,color = "darkorange")
plt.xlabel("Real Data")
plt.ylabel("Predicted")
plt.figure(figsize=(20 , 10))
plt.plot([y_val.min(), y_val.max()], [y_val.min(), y_val.max()], 'k--', lw=4)
print("R^2 = %0.4f" %RR)


plt.subplot(1, 2, 2)
plt.title("Regression Error Characteristic (REC)")
plt.plot(Deviation, Accuracy, "--b",lw =3)
plt.xlabel("Deviation")
plt.ylabel("Accuracy (%)")
plt.text(1.1, 0.07, "AUC = %0.4f" %AUC , fontsize=15)


plt.show()
# Out:
# R^2 = -0.2216
