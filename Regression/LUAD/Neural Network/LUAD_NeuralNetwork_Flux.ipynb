# %%
#importing necessary python packages
import pandas as pd
import numpy as np
import os
from keras.callbacks import ModelCheckpoint
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error 
import warnings 
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', category=DeprecationWarning)
# Out:
# Using TensorFlow backend.

# %%
# Importing the dataset
dt = pd.read_excel('LUAD_flux.xlsx',index_col=0)

# %%
dt.shape
# Out:
# (517, 1962)

# %%
dt.head(2)
# Out:
#                   '3DSPHR'  '3HBCOAHLm'    'ABTArm'     'ABTD'   'ACACT1r'  \
# HUG0_SYMBOL
# TCGA-05-4244-01  11.448262   154.187481 -583.764387 -14.237357  125.403072
# TCGA-05-4249-01   9.173955   162.200877 -442.863722  -5.338254  128.134267
#
#                  'ACACT1rm'   'ACACT1x'  'ACOAD9m'  'ACOAO7p'    'ACOATA'  \
# HUG0_SYMBOL
# TCGA-05-4244-01  235.338244  457.654536  74.716367  72.493260 -165.591744
# TCGA-05-4249-01  137.492687  149.939274  75.026103  56.620656  -73.252506
#
#                  ...  '13HTACRitr'  '1513TACRitr'  '1531TACRitr'  \
# HUG0_SYMBOL      ...
# TCGA-05-4244-01  ...     14.770344      14.770344      14.770344
# TCGA-05-4249-01  ...     34.017476      34.017476      34.017476
#
#                  'DEOXFVSitx'    'FVSitx'  'TACRitr'  '13DMTitr'  '15DMTitr'  \
# HUG0_SYMBOL
# TCGA-05-4244-01   -431.370763  431.370763  26.309675   -6.000452   -6.000452
# TCGA-05-4249-01   -219.803538  219.803538  60.593629  -13.819600  -13.819600
#
#                  '31DMTitr'  Overall Survival (Months)
# HUG0_SYMBOL
# TCGA-05-4244-01   -6.000452                       0.00
# TCGA-05-4249-01  -13.819600                      50.03
#
# [2 rows x 1962 columns]

# %%
X = dt.iloc[:,0:1961].values
y = dt.iloc[:, -1].values

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=0)

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)
X_val = sc_X.fit_transform(X_val)

# %%
sc_y = StandardScaler()
y_train = np.squeeze(sc_y.fit_transform(y_train.reshape(-1, 1)))
y_val = np.squeeze(sc_y.transform(y_val.reshape(-1, 1)))
y_test = np.squeeze(sc_y.transform(y_test.reshape(-1, 1)))

# %%
#Create Deep Neural Network Architecuture
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout

NN_model = Sequential()

# The Input Layer :
NN_model.add(Dense(128, kernel_initializer='normal',input_dim = X_train.shape[1], activation='relu'))

# The Hidden Layers :
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))

# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))

# Compile the network :
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
NN_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               251136
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 416,001
# Trainable params: 416,001
# Non-trainable params: 0
# _________________________________________________________________

# %%
NN_model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split = 0.2)
# Out:
# Train on 264 samples, validate on 66 samples
# Epoch 1/100
# 264/264 [==============================] - 0s 1ms/sample - loss: 0.6839 - mean_absolute_error: 0.6839 - val_loss: 0.5445 - val_mean_absolute_error: 0.5445
# Epoch 2/100
# 264/264 [==============================] - 0s 136us/sample - loss: 0.6273 - mean_absolute_error: 0.6273 - val_loss: 0.4662 - val_mean_absolute_error: 0.4662
# Epoch 3/100
# 264/264 [==============================] - 0s 129us/sample - loss: 0.6101 - mean_absolute_error: 0.6101 - val_loss: 0.5071 - val_mean_absolute_error: 0.5071
# Epoch 4/100
# 264/264 [==============================] - 0s 133us/sample - loss: 0.6330 - mean_absolute_error: 0.6330 - val_loss: 0.4985 - val_mean_absolute_error: 0.4985
# Epoch 5/100
# 264/264 [==============================] - 0s 126us/sample - loss: 0.5662 - mean_absolute_error: 0.5662 - val_loss: 0.4869 - val_mean_absolute_error: 0.4869
# Epoch 6/100
# 264/264 [==============================] - 0s 137us/sample - loss: 0.5508 - mean_absolute_error: 0.5508 - val_loss: 0.5708 - val_mean_absolute_error: 0.5708
# Epoch 7/100
# 264/264 [==============================] - 0s 136us/sample - loss: 0.5195 - mean_absolute_error: 0.5195 - val_loss: 0.4885 - val_mean_absolute_error: 0.4885
# Epoch 8/100
# 264/264 [==============================] - 0s 129us/sample - loss: 0.5090 - mean_absolute_error: 0.5090 - val_loss: 0.5023 - val_mean_absolute_error: 0.5023
# Epoch 9/100
# 264/264 [==============================] - 0s 128us/sample - loss: 0.4970 - mean_absolute_error: 0.4970 - val_loss: 0.4937 - val_mean_absolute_error: 0.4937
# Epoch 10/100
# 264/264 [==============================] - 0s 133us/sample - loss: 0.4875 - mean_absolute_error: 0.4875 - val_loss: 0.5294 - val_mean_absolute_error: 0.5294
# Epoch 11/100
# 264/264 [==============================] - 0s 129us/sample - loss: 0.4719 - mean_absolute_error: 0.4719 - val_loss: 0.5827 - val_mean_absolute_error: 0.5827
# Epoch 12/100
# 264/264 [==============================] - 0s 132us/sample - loss: 0.4516 - mean_absolute_error: 0.4516 - val_loss: 0.5491 - val_mean_absolute_error: 0.5491
# Epoch 13/100
# 264/264 [==============================] - 0s 120us/sample - loss: 0.4403 - mean_absolute_error: 0.4403 - val_loss: 0.6980 - val_mean_absolute_error: 0.6980
# Epoch 14/100
# 264/264 [==============================] - 0s 128us/sample - loss: 0.4396 - mean_absolute_error: 0.4396 - val_loss: 0.4784 - val_mean_absolute_error: 0.4784
# Epoch 15/100
# 264/264 [==============================] - 0s 140us/sample - loss: 0.4585 - mean_absolute_error: 0.4585 - val_loss: 0.5983 - val_mean_absolute_error: 0.5983
# Epoch 16/100
# 264/264 [==============================] - 0s 129us/sample - loss: 0.4338 - mean_absolute_error: 0.4338 - val_loss: 0.5033 - val_mean_absolute_error: 0.5033
# Epoch 17/100
# 264/264 [==============================] - 0s 128us/sample - loss: 0.4400 - mean_absolute_error: 0.4400 - val_loss: 0.5919 - val_mean_absolute_error: 0.5919
# Epoch 18/100
# 264/264 [==============================] - 0s 122us/sample - loss: 0.4023 - mean_absolute_error: 0.4023 - val_loss: 0.6270 - val_mean_absolute_error: 0.6270
# Epoch 19/100
# 264/264 [==============================] - 0s 126us/sample - loss: 0.3674 - mean_absolute_error: 0.3674 - val_loss: 0.7644 - val_mean_absolute_error: 0.7644
# Epoch 20/100
# 264/264 [==============================] - 0s 123us/sample - loss: 0.3599 - mean_absolute_error: 0.3599 - val_loss: 0.6056 - val_mean_absolute_error: 0.6056
# Epoch 21/100
# 264/264 [==============================] - 0s 127us/sample - loss: 0.3811 - mean_absolute_error: 0.3811 - val_loss: 0.5675 - val_mean_absolute_error: 0.5675
# Epoch 22/100
# 264/264 [==============================] - 0s 128us/sample - loss: 0.3579 - mean_absolute_error: 0.3579 - val_loss: 0.6210 - val_mean_absolute_error: 0.6210
# Epoch 23/100
# 264/264 [==============================] - 0s 134us/sample - loss: 0.3568 - mean_absolute_error: 0.3568 - val_loss: 0.5869 - val_mean_absolute_error: 0.5869
# Epoch 24/100
# 264/264 [==============================] - 0s 122us/sample - loss: 0.3196 - mean_absolute_error: 0.3196 - val_loss: 0.6808 - val_mean_absolute_error: 0.6808
# Epoch 25/100
# 264/264 [==============================] - 0s 116us/sample - loss: 0.3110 - mean_absolute_error: 0.3110 - val_loss: 0.6448 - val_mean_absolute_error: 0.6448
# Epoch 26/100
# 264/264 [==============================] - 0s 116us/sample - loss: 0.2820 - mean_absolute_error: 0.2820 - val_loss: 0.6614 - val_mean_absolute_error: 0.6614
# Epoch 27/100
# 264/264 [==============================] - 0s 116us/sample - loss: 0.2947 - mean_absolute_error: 0.2947 - val_loss: 0.7084 - val_mean_absolute_error: 0.7084
# Epoch 28/100
# 264/264 [==============================] - 0s 117us/sample - loss: 0.2836 - mean_absolute_error: 0.2836 - val_loss: 0.6381 - val_mean_absolute_error: 0.6381
# Epoch 29/100
# 264/264 [==============================] - 0s 114us/sample - loss: 0.2768 - mean_absolute_error: 0.2768 - val_loss: 0.7559 - val_mean_absolute_error: 0.7559
# Epoch 30/100
# 264/264 [==============================] - 0s 120us/sample - loss: 0.2664 - mean_absolute_error: 0.2664 - val_loss: 0.7617 - val_mean_absolute_error: 0.7617
# Epoch 31/100
# 264/264 [==============================] - 0s 116us/sample - loss: 0.2648 - mean_absolute_error: 0.2648 - val_loss: 0.5560 - val_mean_absolute_error: 0.5560
# Epoch 32/100
# 264/264 [==============================] - 0s 114us/sample - loss: 0.3013 - mean_absolute_error: 0.3013 - val_loss: 0.7566 - val_mean_absolute_error: 0.7566
# Epoch 33/100
# 264/264 [==============================] - 0s 120us/sample - loss: 0.2427 - mean_absolute_error: 0.2427 - val_loss: 0.5924 - val_mean_absolute_error: 0.5924
# Epoch 34/100
# 264/264 [==============================] - 0s 122us/sample - loss: 0.2575 - mean_absolute_error: 0.2575 - val_loss: 0.8007 - val_mean_absolute_error: 0.8007
# Epoch 35/100
# 264/264 [==============================] - 0s 126us/sample - loss: 0.2858 - mean_absolute_error: 0.2858 - val_loss: 0.5294 - val_mean_absolute_error: 0.5294
# Epoch 36/100
# 264/264 [==============================] - 0s 162us/sample - loss: 0.2893 - mean_absolute_error: 0.2893 - val_loss: 0.5544 - val_mean_absolute_error: 0.5544
# Epoch 37/100
# 264/264 [==============================] - 0s 153us/sample - loss: 0.2553 - mean_absolute_error: 0.2553 - val_loss: 0.7860 - val_mean_absolute_error: 0.7860
# Epoch 38/100
# 264/264 [==============================] - 0s 149us/sample - loss: 0.2362 - mean_absolute_error: 0.2362 - val_loss: 0.6154 - val_mean_absolute_error: 0.6154
# Epoch 39/100
# 264/264 [==============================] - 0s 145us/sample - loss: 0.2215 - mean_absolute_error: 0.2215 - val_loss: 0.7314 - val_mean_absolute_error: 0.7314
# Epoch 40/100
# 264/264 [==============================] - 0s 130us/sample - loss: 0.2477 - mean_absolute_error: 0.2477 - val_loss: 0.5470 - val_mean_absolute_error: 0.5470
# Epoch 41/100
# 264/264 [==============================] - 0s 135us/sample - loss: 0.2768 - mean_absolute_error: 0.2768 - val_loss: 0.7914 - val_mean_absolute_error: 0.7914
# Epoch 42/100
# 264/264 [==============================] - 0s 118us/sample - loss: 0.2565 - mean_absolute_error: 0.2565 - val_loss: 0.6905 - val_mean_absolute_error: 0.6905
# Epoch 43/100
# 264/264 [==============================] - 0s 114us/sample - loss: 0.2129 - mean_absolute_error: 0.2129 - val_loss: 0.7227 - val_mean_absolute_error: 0.7227
# Epoch 44/100
# 264/264 [==============================] - 0s 115us/sample - loss: 0.1877 - mean_absolute_error: 0.1877 - val_loss: 0.5191 - val_mean_absolute_error: 0.5191
# Epoch 45/100
# 264/264 [==============================] - 0s 115us/sample - loss: 0.2296 - mean_absolute_error: 0.2296 - val_loss: 0.7537 - val_mean_absolute_error: 0.7537
# Epoch 46/100
# 264/264 [==============================] - 0s 141us/sample - loss: 0.2146 - mean_absolute_error: 0.2146 - val_loss: 0.5489 - val_mean_absolute_error: 0.5489
# Epoch 47/100
# 264/264 [==============================] - 0s 134us/sample - loss: 0.1947 - mean_absolute_error: 0.1947 - val_loss: 0.8122 - val_mean_absolute_error: 0.8122
# Epoch 48/100
# 264/264 [==============================] - 0s 124us/sample - loss: 0.1728 - mean_absolute_error: 0.1728 - val_loss: 0.6937 - val_mean_absolute_error: 0.6937
# Epoch 49/100
# 264/264 [==============================] - 0s 127us/sample - loss: 0.1694 - mean_absolute_error: 0.1694 - val_loss: 0.6768 - val_mean_absolute_error: 0.6768
# Epoch 50/100
# 264/264 [==============================] - 0s 121us/sample - loss: 0.1586 - mean_absolute_error: 0.1586 - val_loss: 0.7227 - val_mean_absolute_error: 0.7227
# Epoch 51/100
# 264/264 [==============================] - 0s 133us/sample - loss: 0.1797 - mean_absolute_error: 0.1797 - val_loss: 0.6903 - val_mean_absolute_error: 0.6903
# Epoch 52/100
# 264/264 [==============================] - 0s 133us/sample - loss: 0.1839 - mean_absolute_error: 0.1839 - val_loss: 0.5518 - val_mean_absolute_error: 0.5518
# Epoch 53/100
# 264/264 [==============================] - 0s 129us/sample - loss: 0.2338 - mean_absolute_error: 0.2338 - val_loss: 0.5491 - val_mean_absolute_error: 0.5491
# Epoch 54/100
# 264/264 [==============================] - 0s 131us/sample - loss: 0.2102 - mean_absolute_error: 0.2102 - val_loss: 0.6732 - val_mean_absolute_error: 0.6732
# Epoch 55/100
# 264/264 [==============================] - 0s 132us/sample - loss: 0.1559 - mean_absolute_error: 0.1559 - val_loss: 0.7429 - val_mean_absolute_error: 0.7429
# Epoch 56/100
# 264/264 [==============================] - 0s 132us/sample - loss: 0.1433 - mean_absolute_error: 0.1433 - val_loss: 0.7088 - val_mean_absolute_error: 0.7088
# Epoch 57/100
# 264/264 [==============================] - 0s 131us/sample - loss: 0.1433 - mean_absolute_error: 0.1433 - val_loss: 0.7443 - val_mean_absolute_error: 0.7443
# Epoch 58/100
# 264/264 [==============================] - 0s 125us/sample - loss: 0.1241 - mean_absolute_error: 0.1241 - val_loss: 0.6754 - val_mean_absolute_error: 0.6754
# Epoch 59/100
# 264/264 [==============================] - 0s 117us/sample - loss: 0.1392 - mean_absolute_error: 0.1392 - val_loss: 0.7678 - val_mean_absolute_error: 0.7678
# Epoch 60/100
# 264/264 [==============================] - 0s 120us/sample - loss: 0.1269 - mean_absolute_error: 0.1269 - val_loss: 0.6129 - val_mean_absolute_error: 0.6129
# Epoch 61/100
# 264/264 [==============================] - 0s 115us/sample - loss: 0.1266 - mean_absolute_error: 0.1266 - val_loss: 0.7561 - val_mean_absolute_error: 0.7561
# Epoch 62/100
# 264/264 [==============================] - 0s 121us/sample - loss: 0.1445 - mean_absolute_error: 0.1445 - val_loss: 0.6722 - val_mean_absolute_error: 0.6722
# Epoch 63/100
# 264/264 [==============================] - 0s 120us/sample - loss: 0.1438 - mean_absolute_error: 0.1438 - val_loss: 0.6712 - val_mean_absolute_error: 0.6712
# Epoch 64/100
# 264/264 [==============================] - 0s 123us/sample - loss: 0.1431 - mean_absolute_error: 0.1431 - val_loss: 0.6253 - val_mean_absolute_error: 0.6253
# Epoch 65/100
# 264/264 [==============================] - 0s 125us/sample - loss: 0.1252 - mean_absolute_error: 0.1252 - val_loss: 0.7880 - val_mean_absolute_error: 0.7880
# Epoch 66/100
# 264/264 [==============================] - 0s 126us/sample - loss: 0.1228 - mean_absolute_error: 0.1228 - val_loss: 0.7316 - val_mean_absolute_error: 0.7316
# Epoch 67/100
# 264/264 [==============================] - 0s 138us/sample - loss: 0.1237 - mean_absolute_error: 0.1237 - val_loss: 0.6123 - val_mean_absolute_error: 0.6123
# Epoch 68/100
# 264/264 [==============================] - 0s 134us/sample - loss: 0.1343 - mean_absolute_error: 0.1343 - val_loss: 0.8341 - val_mean_absolute_error: 0.8341
# Epoch 69/100
# 264/264 [==============================] - 0s 141us/sample - loss: 0.1896 - mean_absolute_error: 0.1896 - val_loss: 0.6425 - val_mean_absolute_error: 0.6425
# Epoch 70/100
# 264/264 [==============================] - 0s 139us/sample - loss: 0.1385 - mean_absolute_error: 0.1385 - val_loss: 0.8075 - val_mean_absolute_error: 0.8075
# Epoch 71/100
# 264/264 [==============================] - 0s 131us/sample - loss: 0.1376 - mean_absolute_error: 0.1376 - val_loss: 0.7379 - val_mean_absolute_error: 0.7379
# Epoch 72/100
# 264/264 [==============================] - 0s 130us/sample - loss: 0.1381 - mean_absolute_error: 0.1381 - val_loss: 0.6705 - val_mean_absolute_error: 0.6705
# Epoch 73/100
# 264/264 [==============================] - 0s 139us/sample - loss: 0.1291 - mean_absolute_error: 0.1291 - val_loss: 0.7735 - val_mean_absolute_error: 0.7735
# Epoch 74/100
# 264/264 [==============================] - 0s 130us/sample - loss: 0.1366 - mean_absolute_error: 0.1366 - val_loss: 0.5862 - val_mean_absolute_error: 0.5862
# Epoch 75/100
# 264/264 [==============================] - 0s 123us/sample - loss: 0.1415 - mean_absolute_error: 0.1415 - val_loss: 0.6643 - val_mean_absolute_error: 0.6643
# Epoch 76/100
# 264/264 [==============================] - 0s 128us/sample - loss: 0.1296 - mean_absolute_error: 0.1296 - val_loss: 0.7669 - val_mean_absolute_error: 0.7669
# Epoch 77/100
# 264/264 [==============================] - 0s 125us/sample - loss: 0.1031 - mean_absolute_error: 0.1031 - val_loss: 0.7271 - val_mean_absolute_error: 0.7271
# Epoch 78/100
# 264/264 [==============================] - 0s 126us/sample - loss: 0.1413 - mean_absolute_error: 0.1413 - val_loss: 0.6971 - val_mean_absolute_error: 0.6971
# Epoch 79/100
# 264/264 [==============================] - 0s 128us/sample - loss: 0.1134 - mean_absolute_error: 0.1134 - val_loss: 0.8025 - val_mean_absolute_error: 0.8025
# Epoch 80/100
# 264/264 [==============================] - 0s 125us/sample - loss: 0.0955 - mean_absolute_error: 0.0955 - val_loss: 0.6142 - val_mean_absolute_error: 0.6142
# Epoch 81/100
# 264/264 [==============================] - 0s 136us/sample - loss: 0.1068 - mean_absolute_error: 0.1068 - val_loss: 0.7191 - val_mean_absolute_error: 0.7191
# Epoch 82/100
# 264/264 [==============================] - 0s 139us/sample - loss: 0.0943 - mean_absolute_error: 0.0943 - val_loss: 0.7111 - val_mean_absolute_error: 0.7111
# Epoch 83/100
# 264/264 [==============================] - 0s 125us/sample - loss: 0.0941 - mean_absolute_error: 0.0941 - val_loss: 0.7054 - val_mean_absolute_error: 0.7054
# Epoch 84/100
# 264/264 [==============================] - 0s 128us/sample - loss: 0.0939 - mean_absolute_error: 0.0939 - val_loss: 0.7823 - val_mean_absolute_error: 0.7823
# Epoch 85/100
# 264/264 [==============================] - 0s 122us/sample - loss: 0.0983 - mean_absolute_error: 0.0983 - val_loss: 0.6980 - val_mean_absolute_error: 0.6980
# Epoch 86/100
# 264/264 [==============================] - 0s 121us/sample - loss: 0.1093 - mean_absolute_error: 0.1093 - val_loss: 0.7198 - val_mean_absolute_error: 0.7198
# Epoch 87/100
# 264/264 [==============================] - 0s 119us/sample - loss: 0.1048 - mean_absolute_error: 0.1048 - val_loss: 0.8083 - val_mean_absolute_error: 0.8083
# Epoch 88/100
# 264/264 [==============================] - 0s 122us/sample - loss: 0.0946 - mean_absolute_error: 0.0946 - val_loss: 0.7162 - val_mean_absolute_error: 0.7162
# Epoch 89/100
# 264/264 [==============================] - 0s 124us/sample - loss: 0.0844 - mean_absolute_error: 0.0844 - val_loss: 0.6530 - val_mean_absolute_error: 0.6530
# Epoch 90/100
# 264/264 [==============================] - 0s 124us/sample - loss: 0.0936 - mean_absolute_error: 0.0936 - val_loss: 0.7424 - val_mean_absolute_error: 0.7424
# Epoch 91/100
# 264/264 [==============================] - 0s 124us/sample - loss: 0.0745 - mean_absolute_error: 0.0745 - val_loss: 0.6920 - val_mean_absolute_error: 0.6920
# Epoch 92/100
# 264/264 [==============================] - 0s 122us/sample - loss: 0.0717 - mean_absolute_error: 0.0717 - val_loss: 0.7263 - val_mean_absolute_error: 0.7263
# Epoch 93/100
# 264/264 [==============================] - 0s 124us/sample - loss: 0.0862 - mean_absolute_error: 0.0862 - val_loss: 0.6868 - val_mean_absolute_error: 0.6868
# Epoch 94/100
# 264/264 [==============================] - 0s 125us/sample - loss: 0.0788 - mean_absolute_error: 0.0788 - val_loss: 0.7167 - val_mean_absolute_error: 0.7167
# Epoch 95/100
# 264/264 [==============================] - 0s 121us/sample - loss: 0.0764 - mean_absolute_error: 0.0764 - val_loss: 0.7132 - val_mean_absolute_error: 0.7132
# Epoch 96/100
# 264/264 [==============================] - 0s 127us/sample - loss: 0.0884 - mean_absolute_error: 0.0884 - val_loss: 0.7117 - val_mean_absolute_error: 0.7117
# Epoch 97/100
# 264/264 [==============================] - 0s 131us/sample - loss: 0.0946 - mean_absolute_error: 0.0946 - val_loss: 0.7483 - val_mean_absolute_error: 0.7483
# Epoch 98/100
# 264/264 [==============================] - 0s 123us/sample - loss: 0.0968 - mean_absolute_error: 0.0968 - val_loss: 0.6329 - val_mean_absolute_error: 0.6329
# Epoch 99/100
# 264/264 [==============================] - 0s 128us/sample - loss: 0.1146 - mean_absolute_error: 0.1146 - val_loss: 0.6924 - val_mean_absolute_error: 0.6924
# Epoch 100/100
# 264/264 [==============================] - 0s 126us/sample - loss: 0.1274 - mean_absolute_error: 0.1274 - val_loss: 0.6840 - val_mean_absolute_error: 0.6840

# %%
#Predicting the Validation set results
y_predval = NN_model.predict(X_val)

# %%
# Print result of MAE
from sklearn import metrics
print(metrics.mean_absolute_error(y_val, y_predval))

# Print result of MSE
print(metrics.mean_squared_error(y_val, y_predval))

# Print result of RMSE
print(np.sqrt(metrics.mean_squared_error(y_val, y_predval)))

from sklearn.metrics import r2_score
accuracy=r2_score(y_val,y_predval)

print('R2 Score')
print(accuracy)
# Out:
# 0.7818646572696767
# 1.1117946331334574
# 1.0544167265049704
# R2 Score
# -0.5594682538894995

# %%
# Visualising the Random Forest Regression Results
# Loading Packages
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import r2_score
#from sklearn import linear_model
from sklearn import datasets
from scipy.integrate import simps

# Function for Regression Error Characteritic Curve

def REC(y_val , y_predval):
    
    # initilizing the lists
    Accuracy = []
    
    # initializing the values for Epsilon
    Begin_Range = 0
    End_Range = 1.5
    Interval_Size = 0.01
    
    # List of epsilons
    Epsilon = np.arange(Begin_Range , End_Range , Interval_Size)
    
    # Main Loops
    for i in range(len(Epsilon)):
        count = 0.0
        for j in range(len(y_val)):
            if np.linalg.norm(y_val[j] - y_predval[j]) / np.sqrt( np.linalg.norm(y_val[j]) **2 + np.linalg.norm(y_predval[j])**2 ) < Epsilon[i]:
                count = count + 1
        
        Accuracy.append(count/len(y_val))
    
    # Calculating Area Under Curve using Simpson's rule
    AUC = simps(Accuracy , Epsilon ) / End_Range
        
    # returning epsilon , accuracy , area under curve    
    return Epsilon , Accuracy , AUC

# finding the deviation and accuracy, and area under curve for plotting
Deviation, Accuracy, AUC = REC(y_val, y_predval)

# Calculating R^2 of the true and predicted values
RR = r2_score(y_val, y_predval)

# Plotting
plt.figure(figsize=(20 , 10))

plt.subplot(1, 2, 1)
plt.scatter(y_val, y_predval,color = "darkorange")
plt.xlabel("Real Data")
plt.ylabel("Predicted")
plt.figure(figsize=(20 , 10))
plt.plot([y_val.min(), y_val.max()], [y_val.min(), y_val.max()], 'k--', lw=4)
print("R^2 = %0.4f" %RR)


plt.subplot(1, 2, 2)
plt.title("Regression Error Characteristic (REC)")
plt.plot(Deviation, Accuracy, "--b",lw =3)
plt.xlabel("Deviation")
plt.ylabel("Accuracy (%)")
plt.text(1.1, 0.07, "AUC = %0.4f" %AUC , fontsize=15)


plt.show()
# Out:
# R^2 = -0.5595
