# %%
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
os.chdir('C:\\Users\\Kanika Saini\\Desktop')

# %%
normal_gene_only=[0.712,0.705,0.714,0.726,0.528]
objects = ('DT', 'GBT', 'RF', 'SVR', 'Cox(C-index)')
y_pos = np.arange(len(objects))


plt.bar(y_pos, normal_gene_only, align='center', alpha=0.5,color='green')
plt.xticks(y_pos, objects)
plt.ylabel('AUC')
plt.title('AUC for gene only dataset (Normal)')

plt.show()
plt.savefig('AUC_gene_Only_Normal.pdf')

# %%
normal_flux_only=[0.729,0.724,0.724,0.732,0.522]
objects = ('DT', 'GBT', 'RF', 'SVR', 'Cox(C-index)')
y_pos = np.arange(len(objects))


plt.bar(y_pos, normal_flux_only, align='center', alpha=0.5,color='green')
plt.xticks(y_pos, objects)
plt.ylabel('AUC')
plt.title('AUC for Flux only dataset (Normal)')

plt.show()
plt.savefig('AUC_Flux_Only_Normal.pdf')

# %%
normal_clinical_only=[0.712,0.705,0.714,0.726,0.528]
objects = ('DT', 'GBT', 'RF', 'SVR', 'Cox(C-index)')
y_pos = np.arange(len(objects))


plt.bar(y_pos, normal_clinical_only, align='center', alpha=0.5,color='green')
plt.xticks(y_pos, objects)
plt.ylabel('AUC')
plt.title('AUC for Clinical only dataset (Normal)')

plt.show()
plt.savefig('AUC_Clinical_Only_Normal.pdf')

# %%
normal_flux_genes_only=[0.715,0.714,0.71,0.726,0.513]
objects = ('DT', 'GBT', 'RF', 'SVR', 'Cox(C-index)')
y_pos = np.arange(len(objects)) 


plt.bar(y_pos, normal_flux_genes_only, align='center', alpha=0.5,color='green')
plt.xticks(y_pos, objects)
plt.ylabel('AUC')
plt.title('AUC for flux genes only dataset (Normal)')

plt.show()
plt.savefig('AUC_flux_genes_Only_Normal.pdf')

# %%
normal_gene_clinical=[0.748,0.763,0.749,0.733,0.704]
objects = ('DT', 'GBT', 'RF', 'SVR', 'Cox(C-index)')
y_pos = np.arange(len(objects))


plt.bar(y_pos, normal_gene_clinical, align='center', alpha=0.5,color='green')
plt.xticks(y_pos, objects)
plt.ylabel('AUC')
plt.title('AUC for Gene Clinical dataset (Normal)')

plt.show()
plt.savefig('AUC_Gene_Clinical_Normal.pdf')

# %%
normal_flux_clinical=[0.743,0.744,0.75,0.735,0.552 ]
objects = ('DT', 'GBT', 'RF', 'SVR', 'Cox(C-index)')
y_pos = np.arange(len(objects))


plt.bar(y_pos, normal_flux_clinical, align='center', alpha=0.5,color='green')
plt.xticks(y_pos, objects)
plt.ylabel('AUC')
plt.title('AUC for Flux Clinical dataset (Normal)')

plt.show()
plt.savefig('AUC_Flux_Clinical_Normal.pdf')

# %%
normal_all=[0.74,0.735,0.738,0.726,0.546]
objects = ('DT', 'GBT', 'RF', 'SVR', 'Cox(C-index)')
y_pos = np.arange(len(objects))
plt.bar(y_pos, normal_all, align='center', alpha=0.5,color='green')
plt.xticks(y_pos, objects)
plt.ylabel('AUC')
plt.title('AUC for ALL dataset (Normal)')

plt.show()
plt.savefig('AUC_ALL_Normal.pdf')

# %%
                        '''PCA'''

# %%
normal_clinical_only=[0.746,0.756,0.748,0.743,0.783]
objects = ('DT', 'GBT', 'RF', 'SVR', 'Cox(C-index)')
y_pos = np.arange(len(objects))


plt.bar(y_pos, normal_clinical_only, align='center', alpha=0.5,color='green')
plt.xticks(y_pos, objects)
plt.ylabel('AUC')
plt.title('AUC for Clinical only dataset (Normal)')

plt.show()
plt.savefig('AUC_Clinical_Only_PCA.pdf')

# %%
normal_flux_only=[0.72,0.723,0.725,0.736,0.461]
objects = ('DT', 'GBT', 'RF', 'SVR', 'Cox(C-index)')
y_pos = np.arange(len(objects))


plt.bar(y_pos, normal_flux_only, align='center', alpha=0.5,color='green')
plt.xticks(y_pos, objects)
plt.ylabel('AUC')
plt.title('AUC for Flux only dataset (Normal)') 

plt.show()
plt.savefig('AUC_Flux_Only_PCA.pdf')

# %%
normal_gene_only=[0.714,0.713,0.716,0.726,0.535]
objects = ('DT', 'GBT', 'RF', 'SVR', 'Cox(C-index)')
y_pos = np.arange(len(objects))


plt.bar(y_pos, normal_gene_only, align='center', alpha=0.5,color='green')
plt.xticks(y_pos, objects)
plt.ylabel('AUC')
plt.title('AUC for gene only dataset (Normal)')

plt.show()
plt.savefig('AUC_gene_Only_PCA.pdf')

# %%
normal_clinical_flux_only=[0.724,0.724,0.724,0.736,0.469]
objects = ('DT', 'GBT', 'RF', 'SVR', 'Cox(C-index)')
y_pos = np.arange(len(objects)) 


plt.bar(y_pos, normal_clinical_flux_only, align='center', alpha=0.5,color='green')
plt.xticks(y_pos, objects)
plt.ylabel('AUC')
plt.title('AUC for clinical flux only dataset (Normal)')

plt.show()
plt.savefig('AUC_clinical_flux_Only_PCA.pdf')

# %%
normal_clinical_genes_only=[0.721,0.723,0.724,0.736,0.528]
objects = ('DT', 'GBT', 'RF', 'SVR', 'Cox(C-index)')
y_pos = np.arange(len(objects)) 


plt.bar(y_pos, normal_clinical_genes_only, align='center', alpha=0.5,color='green')
plt.xticks(y_pos, objects)
plt.ylabel('AUC')
plt.title('AUC for clinical genes only dataset (Normal)')

plt.show()
plt.savefig('AUC_clinical_genes_Only_PCA.pdf')

# %%
normal_flux_genes_only=[0.721,0.723,0.724,0.736,0.528]
objects = ('DT', 'GBT', 'RF', 'SVR', 'Cox(C-index)')
y_pos = np.arange(len(objects)) 


plt.bar(y_pos, normal_flux_genes_only, align='center', alpha=0.5,color='green')
plt.xticks(y_pos, objects)
plt.ylabel('AUC')
plt.title('AUC for flux genes only dataset (Normal)')

plt.show()
plt.savefig('AUC_flux_genes_Only_PCA.pdf')

# %%
normal_all=[0.713,0.713,0.714,0.726,0.508]
objects = ('DT', 'GBT', 'RF', 'SVR', 'Cox(C-index)')
y_pos = np.arange(len(objects)) 


plt.bar(y_pos, normal_all, align='center', alpha=0.5,color='green')
plt.xticks(y_pos, objects)
plt.ylabel('AUC')
plt.title('AUC for all dataset (Normal)')

plt.show()
plt.savefig('AUC_all_Only_PCA.pdf')

# %%
                                              '''RF'''

# %%
normal_clinical_only=[0.748,0.768,0.77,0.752,0.781]
objects = ('DT', 'GBT', 'RF', 'SVR', 'Cox(C-index)')
y_pos = np.arange(len(objects))


plt.bar(y_pos, normal_clinical_only, align='center', alpha=0.5,color='green')
plt.xticks(y_pos, objects)
plt.ylabel('AUC')
plt.title('AUC for Clinical only dataset (Normal)')

plt.show()
plt.savefig('AUC_Clinical_Only_RF.pdf')

# %%
normal_flux_only=[0.723,0.722,0.725,0.733,0.496]
objects = ('DT', 'GBT', 'RF', 'SVR', 'Cox(C-index)')
y_pos = np.arange(len(objects))


plt.bar(y_pos, normal_flux_only, align='center', alpha=0.5,color='green')
plt.xticks(y_pos, objects)
plt.ylabel('AUC')
plt.title('AUC for Flux only dataset (Normal)') 

plt.show()
plt.savefig('AUC_Flux_Only_RF.pdf')

# %%
normal_gene_only=[0.706,0.712,0.713,0.724,0.563]
objects = ('DT', 'GBT', 'RF', 'SVR', 'Cox(C-index)')
y_pos = np.arange(len(objects))


plt.bar(y_pos, normal_gene_only, align='center', alpha=0.5,color='green')
plt.xticks(y_pos, objects)
plt.ylabel('AUC')
plt.title('AUC for gene only dataset (Normal)')

plt.show()
plt.savefig('AUC_gene_Only_RF.pdf')

# %%
normal_clinical_flux_only=[0.752,0.756,0.75,0.737,0.755]
objects = ('DT', 'GBT', 'RF', 'SVR', 'Cox(C-index)')
y_pos = np.arange(len(objects)) 


plt.bar(y_pos, normal_clinical_flux_only, align='center', alpha=0.5,color='green')
plt.xticks(y_pos, objects)
plt.ylabel('AUC')
plt.title('AUC for clinical flux only dataset (Normal)')

plt.show()
plt.savefig('AUC_clinical_flux_Only_RF.pdf')

# %%
normal_clinical_genes_only=[0.763,0.742,0.756,0.736,0.675]
objects = ('DT', 'GBT', 'RF', 'SVR', 'Cox(C-index)')
y_pos = np.arange(len(objects)) 


plt.bar(y_pos, normal_clinical_genes_only, align='center', alpha=0.5,color='green')
plt.xticks(y_pos, objects)
plt.ylabel('AUC')
plt.title('AUC for clinical genes only dataset (Normal)')

plt.show()
plt.savefig('AUC_clinical_genes_Only_RF.pdf')

# %%
normal_flux_genes_only=[0.714,0.716,0.708,0.727,0.572]
objects = ('DT', 'GBT', 'RF', 'SVR', 'Cox(C-index)')
y_pos = np.arange(len(objects)) 


plt.bar(y_pos, normal_flux_genes_only, align='center', alpha=0.5,color='green')
plt.xticks(y_pos, objects)
plt.ylabel('AUC')
plt.title('AUC for flux genes only dataset (Normal)')

plt.show()
plt.savefig('AUC_flux_genes_Only_RF.pdf')

# %%
normal_all=[0.738,0.73,0.741,0.726,0.620]
objects = ('DT', 'GBT', 'RF', 'SVR', 'Cox(C-index)')
y_pos = np.arange(len(objects)) 


plt.bar(y_pos, normal_all, align='center', alpha=0.5,color='green')
plt.xticks(y_pos, objects)
plt.ylabel('AUC')
plt.title('AUC for all dataset (Normal)')

plt.show()
plt.savefig('AUC_all_Only_ RF.pdf')
